# %% [markdown]
# # FIT5196 Assessment 1: Text Processing
# #### Student Name:
# #### Student ID:
#
# Date:
#
# Environment: Python 2.7.11 and Jupyter notebook
# Libraries used:
# * BeautifulSoup (for XML parsing)
# * nltk - natural language toolkit (tokenizer, lemmatizer, stopwords, collocations and probabilities)
# * re (for regular expression, included in Anaconda Python 2.7)
# * matplotlib (for plotting)
#
#
# ## 1. Introduction
# This analysis extracts data from an XML-based corpus containing 2500 patent documents. Data was extracted by reading the input file 'patents/patents.xml', splitting at the document boundaries (i.e. XML headers) and then creating a list where each item in the list holds the full XML for each individual patent.
#
# Data relating to patent classifications and citations was extracted using the package `BeautfulSoup` to extract values from specific XML tags. Similarly, the text associated with abstracts was extracted for further pre-processing.
#
# Text pre-processing was performed with the objective of producing a lexical vocabulary for the patents and the associated sparse count vector for each abstract. The pre-processing included tokenisation, lemmatisation and removal of stopwords. Additionally, the most frequent and least frequent words were removed, and meaningful bigrams were identified.  The initial tokenised vocabulary of the corpus was 9690 words, which was reduced to 4906 words following pre-processing.

# %% [markdown]
# ## 2.  Import libraries

# %% [markdown]
# ## 3. Examining and loading data

# %% [markdown]
# The file "patents.xml" contains 2500 patents. Each patent is structured in an XML file. In order to process the data, the xml associated with each patent is identified using a regular expression.
#
# The initial processing is memory efficient and fast, and creates a list of length 2500, with each item in the list containing the full xml for each patent.

# %% [markdown]
# ### 3.1 Inital loading patent.xml file

# %%
# Out:
# Total Lines read:  1791369
# Number of XML headers:  2500

# %% [markdown]
# ### 3.2 Identifying the XML structure
# The package 'BeautifulSoup' is used to explore the xml structure, and to extract the required information.
# The full xml tree for the first patent is shown below.

# %%
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE us-patent-grant SYSTEM "us-patent-grant-v42-2006-08-23.dtd">
# <us-patent-grant country="US" date-produced="20110208" date-publ="20110222" dtd-version="v4.2 2006-08-23" file="USPP021722-20110222.XML" id="us-patent-grant" lang="EN" status="PRODUCTION">
#  <us-bibliographic-data-grant>
#   <publication-reference>
#    <document-id>
#     <country>
#      US
#     </country>
#     <doc-number>
#      PP021722
#     </doc-number>
#     <kind>
#      P3
#     </kind>
#     <date>
#      20110222
#     </date>
#    </document-id>
#   </publication-reference>
#   <application-reference appl-type="plant">
#    <document-id>
#     <country>
#      US
#     </country>
#     <doc-number>
#      12316880
#     </doc-number>
#     <date>
#      20081216
#     </date>
#    </document-id>
#   </application-reference>
#   <us-application-series-code>
#    12
#   </us-application-series-code>
#   <us-term-of-grant>
#    <us-term-extension>
#     108
#    </us-term-extension>
#   </us-term-of-grant>
#   <classifications-ipcr>
#    <classification-ipcr>
#     <ipc-version-indicator>
#      <date>
#       20060101
#      </date>
#     </ipc-version-indicator>
#     <classification-level>
#      A
#     </classification-level>
#     <section>
#      A
#     </section>
#     <class>
#      01
#     </class>
#     <subclass>
#      H
#     </subclass>
#     <main-group>
#      5
#     </main-group>
#     <subgroup>
#      00
#     </subgroup>
#     <symbol-position>
#      F
#     </symbol-position>
#     <classification-value>
#      I
#     </classification-value>
#     <action-date>
#      <date>
#       20110222
#      </date>
#     </action-date>
#     <generating-office>
#      <country>
#       US
#      </country>
#     </generating-office>
#     <classification-status>
#      B
#     </classification-status>
#     <classification-data-source>
#      H
#     </classification-data-source>
#    </classification-ipcr>
#   </classifications-ipcr>
#   <classification-national>
#    <country>
#     US
#    </country>
#    <main-classification>
#     PLT161
#    </main-classification>
#   </classification-national>
#   <invention-title id="d2e53">
#    Apple tree named ‘Daligris’
#   </invention-title>
#   <us-botanic>
#    <latin-name>
#     Malus domestica Borkh
#    </latin-name>
#    <variety>
#     Daligris
#    </variety>
#   </us-botanic>
#   <references-cited>
#    <citation>
#     <patcit num="00001">
#      <document-id>
#       <country>
#        US
#       </country>
#       <doc-number>
#        PP17672
#       </doc-number>
#       <kind>
#        P3
#       </kind>
#       <name>
#        Hofmann
#       </name>
#       <date>
#        20070500
#       </date>
#      </document-id>
#     </patcit>
#     <category>
#      cited by examiner
#     </category>
#     <classification-national>
#      <country>
#       US
#      </country>
#      <main-classification>
#       PLT161
#      </main-classification>
#     </classification-national>
#    </citation>
#    <citation>
#     <patcit num="00002">
#      <document-id>
#       <country>
#        US
#       </country>
#       <doc-number>
#        PP18482
#       </doc-number>
#       <kind>
#        P3
#       </kind>
#       <name>
#        Ligonniere
#       </name>
#       <date>
#        20080200
#       </date>
#      </document-id>
#     </patcit>
#     <category>
#      cited by examiner
#     </category>
#     <classification-national>
#      <country>
#       US
#      </country>
#      <main-classification>
#       PLT161
#      </main-classification>
#     </classification-national>
#    </citation>
#    <citation>
#     <patcit num="00003">
#      <document-id>
#       <country>
#        US
#       </country>
#       <doc-number>
#        PP18483
#       </doc-number>
#       <kind>
#        P3
#       </kind>
#       <name>
#        Ligonniere
#       </name>
#       <date>
#        20080200
#       </date>
#      </document-id>
#     </patcit>
#     <category>
#      cited by examiner
#     </category>
#     <classification-national>
#      <country>
#       US
#      </country>
#      <main-classification>
#       PLT161
#      </main-classification>
#     </classification-national>
#    </citation>
#   </references-cited>
#   <number-of-claims>
#    1
#   </number-of-claims>
#   <us-exemplary-claim>
#    1
#   </us-exemplary-claim>
#   <us-field-of-classification-search>
#    <classification-national>
#     <country>
#      US
#     </country>
#     <main-classification>
#      PLT161
#     </main-classification>
#    </classification-national>
#   </us-field-of-classification-search>
#   <figures>
#    <number-of-drawing-sheets>
#     4
#    </number-of-drawing-sheets>
#    <number-of-figures>
#     4
#    </number-of-figures>
#   </figures>
#   <us-related-documents>
#    <related-publication>
#     <document-id>
#      <country>
#       US
#      </country>
#      <doc-number>
#       20100154089
#      </doc-number>
#      <kind>
#       P1
#      </kind>
#      <date>
#       20100617
#      </date>
#     </document-id>
#    </related-publication>
#   </us-related-documents>
#   <parties>
#    <applicants>
#     <applicant app-type="applicant-inventor" designation="us-only" sequence="001">
#      <addressbook>
#       <last-name>
#        Ligonnière
#       </last-name>
#       <first-name>
#        Guy
#       </first-name>
#       <address>
#        <city>
#         Angers
#        </city>
#        <country>
#         FR
#        </country>
#       </address>
#      </addressbook>
#      <nationality>
#       <country>
#        omitted
#       </country>
#      </nationality>
#      <residence>
#       <country>
#        FR
#       </country>
#      </residence>
#     </applicant>
#    </applicants>
#    <agents>
#     <agent rep-type="attorney" sequence="01">
#      <addressbook>
#       <last-name>
#        Bos
#       </last-name>
#       <first-name>
#        Michelle
#       </first-name>
#       <address>
#        <country>
#         unknown
#        </country>
#       </address>
#      </addressbook>
#     </agent>
#    </agents>
#   </parties>
#   <assignees>
#    <assignee>
#     <addressbook>
#      <orgname>
#       S.N.C. Elaris
#      </orgname>
#      <role>
#       03
#      </role>
#      <address>
#       <city>
#        Angers
#       </city>
#       <country>
#        FR
#       </country>
#      </address>
#     </addressbook>
#    </assignee>
#   </assignees>
#   <examiners>
#    <primary-examiner>
#     <last-name>
#      McCormick Ewoldt
#     </last-name>
#     <first-name>
#      Susan B
#     </first-name>
#     <department>
#      1661
#     </department>
#    </primary-examiner>
#   </examiners>
#  </us-bibliographic-data-grant>
#  <abstract id="abstract">
#   <p id="p-0001" num="0000">
#    A new apple tree named ‘Daligris’ is disclosed. The fruit of the new variety is particularly notable for its eating quality and distinctive flavor and appearance. The fruit is very sweet and has a pronounced aniseed flavor, and takes on a distinctive red orange coloration as it ripens on the tree.
#   </p>
#  </abstract>
#  <drawings id="DRAWINGS">
#   <figure id="Fig-EMI-D00001" num="00001">
#    <img alt="embedded image" file="USPP021722-20110222-D00001.TIF" he="183.81mm" id="EMI-D00001" img-content="drawing" img-format="tif" wi="124.21mm"/>
#   </figure>
#   <figure id="Fig-EMI-D00002" num="00002">
#    <img alt="embedded image" file="USPP021722-20110222-D00002.TIF" he="178.90mm" id="EMI-D00002" img-content="drawing" img-format="tif" wi="123.53mm"/>
#   </figure>
#   <figure id="Fig-EMI-D00003" num="00003">
#    <img alt="embedded image" file="USPP021722-20110222-D00003.TIF" he="175.94mm" id="EMI-D00003" img-content="drawing" img-format="tif" wi="119.30mm"/>
#   </figure>
#   <figure id="Fig-EMI-D00004" num="00004">
#    <img alt="embedded image" file="USPP021722-20110222-D00004.TIF" he="175.26mm" id="EMI-D00004" img-content="drawing" img-format="tif" wi="123.53mm"/>
#   </figure>
#  </drawings>
#  <description id="description">
#   <?BRFSUM description="Brief Summary" end="lead"?>
#   <p id="p-0002" num="0001">
#    Latin name:
#    <i>
#     Malus domestica
#    </i>
#    Borkh.
#   </p>
#   <p id="p-0003" num="0002">
#    Variety denomination: ‘Daligris’.
#   </p>
#   <heading id="h-0001" level="1">
#    CROSS REFERENCE TO RELATED APPLICATIONS
#   </heading>
#   <p id="p-0004" num="0003">
#    None.
#   </p>
#   <heading id="h-0002" level="1">
#    PRIORITY CLAIM
#   </heading>
#   <p id="p-0005" num="0004">
#    None.
#   </p>
#   <heading id="h-0003" level="1">
#    STATEMENT REGARDING FEDERALLY SPONSORED RESEARCH OR DEVELOPMENT
#   </heading>
#   <p id="p-0006" num="0005">
#    None.
#   </p>
#   <heading id="h-0004" level="1">
#    BACKGROUND OF THE VARIETY
#   </heading>
#   <p id="p-0007" num="0006">
#    ‘Daligris’ is a new and distinct cultivar of apple tree
#    <i>
#     Malus domestica
#    </i>
#    Borkh. ‘Daligris’ is a whole tree mutation of the apple variety ‘Pinova’ (U.S. Plant Pat. No. 11,601). The original whole tree mutation was discovered during the 1998 harvest in a commercial block of ‘Pinova’ trees near Lezigne-France, planted on M9 rootstocks in 1997. It was first asexually propagated in March 2000 for testing purposes by grafting under the breeder's reference number DDR14-51 at Doue la Fontaine, France. ‘Daligris’ was propagated for further experimentation in 2002.
#   </p>
#   <p id="p-0008" num="0007">
#    The asexually propagated progeny of ‘Daligris’ has consistently been found to be homogeneous and stable, retaining the unique characteristics of the original ‘Daligris’ tree and fruit, and has remained true to type over successive asexually propagated generations. Plant Variety Rights have been applied for ‘Daligris’ in the European Union in 2006 under the application number 2006/1697.
#   </p>
#   <?BRFSUM description="Brief Summary" end="tail"?>
#   <?brief-description-of-drawings description="Brief Description of Drawings" end="lead"?>
#   <description-of-drawings>
#    <heading id="h-0005" level="1">
#     BRIEF DESCRIPTION OF THE VARIETY
#    </heading>
#    <p id="p-0009" num="0008">
#     Trees of ‘Daligris’ have been virus tested, and have been found to be free from the most common apple viruses in Europe (stem pitting, stem grooving, rubbery wood, proliferation, spy decline, chlorotic leaf spot, russet ring, star crack, russet wart, mosaic). Virus free certified material will be available in 2009.
#    </p>
#    <p id="p-0010" num="0009">
#     ‘Daligris’ is quite similar to ‘Pinova’ with respect to tree behavior, flowers, and leaves. However, the fruit of ‘Daligris’ is notably distinct from ‘Pinova,’ and from ‘Dalinip’ (U.S. Plant Pat. No. 18,482), ‘Dalirail’ (U.S. Plant Pat. No. 18,483), and ROHO 3615(U.S. Plant Pat. No. 17,672), each of which is also a mutation of ‘Pinova’.
#    </p>
#    <p id="p-0011" num="0010">
#     <tables id="TABLE-US-00001" num="00001">
#      <table colsep="0" frame="none" rowsep="0">
#       <tgroup align="left" cols="1" colsep="0" rowsep="0">
#        <colspec align="center" colname="1" colwidth="217pt"/>
#        <thead>
#         <row>
#          <entry nameend="1" namest="1" rowsep="1">
#           TABLE 1
#          </entry>
#         </row>
#        </thead>
#        <tbody valign="top">
#         <row>
#          <entry align="center" nameend="1" namest="1" rowsep="1"/>
#         </row>
#         <row>
#          <entry>
#           Comparison of ‘Daligris’ to ‘Pinova’ and Related Varieties
#          </entry>
#         </row>
#         <row>
#          <entry>
#           (measurements given are approximate)
#          </entry>
#         </row>
#        </tbody>
#       </tgroup>
#       <tgroup align="left" cols="6" colsep="0" rowsep="0">
#        <colspec align="left" colname="1" colwidth="35pt"/>
#        <colspec align="left" colname="2" colwidth="35pt"/>
#        <colspec align="left" colname="3" colwidth="42pt"/>
#        <colspec align="left" colname="4" colwidth="35pt"/>
#        <colspec align="left" colname="5" colwidth="35pt"/>
#        <colspec align="left" colname="6" colwidth="35pt"/>
#        <tbody valign="top">
#         <row>
#          <entry>
#           Charac-
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           teristic of
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry>
#           ROHO
#          </entry>
#         </row>
#         <row>
#          <entry>
#           the fruit
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Daligris
#          </entry>
#          <entry>
#           Dalinip
#          </entry>
#          <entry>
#           Dalirail
#          </entry>
#          <entry>
#           3615
#          </entry>
#         </row>
#         <row>
#          <entry align="center" nameend="6" namest="1" rowsep="1"/>
#         </row>
#         <row>
#          <entry>
#           Maturity
#          </entry>
#          <entry>
#           Third
#          </entry>
#          <entry>
#           Fourth
#          </entry>
#          <entry>
#           First
#          </entry>
#          <entry>
#           Second
#          </entry>
#          <entry>
#           Third
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           week of
#          </entry>
#          <entry>
#           week of
#          </entry>
#          <entry>
#           week of
#          </entry>
#          <entry>
#           week of
#          </entry>
#          <entry>
#           week of
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           September
#          </entry>
#          <entry>
#           September
#          </entry>
#          <entry>
#           September
#          </entry>
#          <entry>
#           September
#          </entry>
#          <entry>
#           September
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Amount
#          </entry>
#          <entry>
#           Absent
#          </entry>
#          <entry>
#           Typical
#          </entry>
#          <entry>
#           Absent
#          </entry>
#          <entry>
#           Absent
#          </entry>
#          <entry>
#           Absent
#          </entry>
#         </row>
#         <row>
#          <entry>
#           of
#          </entry>
#          <entry>
#           to very
#          </entry>
#          <entry>
#           light
#          </entry>
#          <entry>
#           to very
#          </entry>
#          <entry>
#           to very
#          </entry>
#          <entry>
#           to very
#          </entry>
#         </row>
#         <row>
#          <entry>
#           russeting
#          </entry>
#          <entry>
#           small
#          </entry>
#          <entry>
#           brown-
#          </entry>
#          <entry>
#           small
#          </entry>
#          <entry>
#           small
#          </entry>
#          <entry>
#           small
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           yellow
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           russeting on
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           25% to 40%
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           of the skin
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           surface
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           Type of
#          </entry>
#          <entry>
#           Red 41A
#          </entry>
#          <entry>
#           Red 41A
#          </entry>
#          <entry>
#           Red 44A
#          </entry>
#          <entry>
#           Red 44A
#          </entry>
#          <entry>
#           Intense
#          </entry>
#         </row>
#         <row>
#          <entry>
#           fore-
#          </entry>
#          <entry/>
#          <entry>
#           to Red-
#          </entry>
#          <entry>
#           to Red-
#          </entry>
#          <entry/>
#          <entry>
#           red
#          </entry>
#         </row>
#         <row>
#          <entry>
#           ground
#          </entry>
#          <entry/>
#          <entry>
#           Orange
#          </entry>
#          <entry>
#           Orange
#          </entry>
#          <entry/>
#          <entry>
#           46A-46B
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Colour
#          </entry>
#          <entry/>
#          <entry>
#           42A
#          </entry>
#          <entry>
#           42A
#          </entry>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           Amount
#          </entry>
#          <entry>
#           25-50%
#          </entry>
#          <entry>
#           10-40%
#          </entry>
#          <entry>
#           60-80%
#          </entry>
#          <entry>
#           50-75%
#          </entry>
#          <entry>
#           60-90%
#          </entry>
#         </row>
#         <row>
#          <entry>
#           of fore-
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           ground
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           Colour
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           Sugar
#          </entry>
#          <entry>
#           High:
#          </entry>
#          <entry>
#           Very high:
#          </entry>
#          <entry>
#           Similar to
#          </entry>
#          <entry>
#           Similar to
#          </entry>
#          <entry>
#           Similar to
#          </entry>
#         </row>
#         <row>
#          <entry>
#           content
#          </entry>
#          <entry>
#           13.4°
#          </entry>
#          <entry>
#           15.5°
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Average
#          </entry>
#          <entry>
#           brix
#          </entry>
#          <entry>
#           brix
#          </entry>
#          <entry>
#           (around
#          </entry>
#          <entry>
#           (around
#          </entry>
#          <entry>
#           (around
#          </entry>
#         </row>
#         <row>
#          <entry>
#           on 20
#          </entry>
#          <entry/>
#          <entry/>
#          <entry>
#           13° brix)
#          </entry>
#          <entry>
#           13° brix)
#          </entry>
#          <entry>
#           13° brix)
#          </entry>
#         </row>
#         <row>
#          <entry>
#           fruits from
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           compara-
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           ble trees
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry>
#           Taste
#          </entry>
#          <entry>
#           Balanced
#          </entry>
#          <entry>
#           Pro-
#          </entry>
#          <entry>
#           Balanced
#          </entry>
#          <entry>
#           Balanced
#          </entry>
#          <entry>
#           Balanced
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           in sugar
#          </entry>
#          <entry>
#           nounced
#          </entry>
#          <entry>
#           in sugar
#          </entry>
#          <entry>
#           in sugar
#          </entry>
#          <entry>
#           in sugar
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           and
#          </entry>
#          <entry>
#           aniseed
#          </entry>
#          <entry>
#           and
#          </entry>
#          <entry>
#           and
#          </entry>
#          <entry>
#           and
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           acidity
#          </entry>
#          <entry>
#           flavor
#          </entry>
#          <entry>
#           acidity
#          </entry>
#          <entry>
#           acidity
#          </entry>
#          <entry>
#           acidity
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           with
#          </entry>
#          <entry/>
#          <entry>
#           with
#          </entry>
#          <entry>
#           with
#          </entry>
#          <entry>
#           with
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           medium
#          </entry>
#          <entry/>
#          <entry>
#           medium
#          </entry>
#          <entry>
#           medium
#          </entry>
#          <entry>
#           medium
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           aroma
#          </entry>
#          <entry/>
#          <entry>
#           aroma
#          </entry>
#          <entry>
#           aroma
#          </entry>
#          <entry>
#           aroma
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Size of
#          </entry>
#          <entry>
#           Small
#          </entry>
#          <entry>
#           Very large
#          </entry>
#          <entry>
#           Small
#          </entry>
#          <entry>
#           Small
#          </entry>
#          <entry>
#           Small
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Lenticels
#          </entry>
#          <entry>
#           (average:
#          </entry>
#          <entry>
#           and very
#          </entry>
#          <entry>
#           (average:
#          </entry>
#          <entry>
#           (average:
#          </entry>
#          <entry>
#           (average:
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry>
#           0.5 mm)
#          </entry>
#          <entry>
#           prominent
#          </entry>
#          <entry>
#           0.5 mm)
#          </entry>
#          <entry>
#           0.5 mm)
#          </entry>
#          <entry>
#           0.5 mm)
#          </entry>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           (average:
#          </entry>
#          <entry/>
#          <entry/>
#          <entry/>
#         </row>
#         <row>
#          <entry/>
#          <entry/>
#          <entry>
#           1.2 mm)
#          </entry>
#         </row>
#         <row>
#          <entry align="center" nameend="6" namest="1" rowsep="1"/>
#         </row>
#        </tbody>
#       </tgroup>
#      </table>
#     </tables>
#    </p>
#    <heading id="h-0006" level="1">
#     The Tree
#    </heading>
#    <p id="p-0012" num="0011">
#     The tree of ‘Daligris’ is a bit more dwarf than ‘Pinova’. The branches, leaves and flowers of ‘Daligris’ are similar to ‘Pinova’. The bloom is also similar to ‘Pinova’ in terms of bloom date range and intensity. Like its parent ‘Pinova’, ‘Daligris’ is very precocious and does not tend to alternate bearing. Productivity is comparable to ‘Pinova’.
#    </p>
#    <heading id="h-0007" level="1">
#     The Fruit
#    </heading>
#    <p id="p-0013" num="0012">
#     ‘Daligris’ is very similar to ‘Pinova’ in term of fruit shape and size. Harvest of ‘Daligris’ has been observed to begin approximately one week later than ‘Pinova’. The storageability of ‘Daligris’ is very similar to ‘Pinova’.
#    </p>
#    <p id="p-0014" num="0013">
#     The fruit of ‘Daligris’ is very distinctive from ‘Pinova’ in appearance:
#     <ul id="ul0001" list-style="none">
#      <li id="ul0001-0001" num="0000">
#       <ul id="ul0002" list-style="none">
#        <li id="ul0002-0001" num="0014">
#         it is partially covered with a smooth light brown to yellow russeting which fully covers the stem cavity and then spreads out on the cheeks of the fruit;
#        </li>
#        <li id="ul0002-0002" num="0015">
#         the lenticels are much larger and much more prominent than on ‘Pinova’. They are russeted and bumpy; and
#        </li>
#        <li id="ul0002-0003" num="0016">
#         ‘Daligris’ has a typical red-orange over-color, as distinguished from the red-pink over-color of ‘Pinova’.
#        </li>
#       </ul>
#      </li>
#     </ul>
#    </p>
#    <p id="p-0015" num="0017">
#     ‘Daligris’ also has a consistent distinctive eating quality:
#     <ul id="ul0003" list-style="none">
#      <li id="ul0003-0001" num="0000">
#       <ul id="ul0004" list-style="none">
#        <li id="ul0004-0001" num="0018">
#         Quantitative analyses (as presented in the table below) show that ‘Daligris’ consistently has a higher sugar content than ‘Pinova’; and
#        </li>
#        <li id="ul0004-0002" num="0019">
#         ‘Daligris’ has a pronounced aniseed flavor which, combined with the high sugar level, gives a unique taste to the variety.
#        </li>
#       </ul>
#      </li>
#     </ul>
#    </p>
#    <p id="p-0016" num="0020">
#     <tables id="TABLE-US-00002" num="00002">
#      <table colsep="0" frame="none" pgwide="1" rowsep="0">
#       <tgroup align="left" cols="1" colsep="0" rowsep="0">
#        <colspec align="center" colname="1" colwidth="259pt"/>
#        <thead>
#         <row>
#          <entry nameend="1" namest="1" rowsep="1">
#           TABLE 2
#          </entry>
#         </row>
#        </thead>
#        <tbody valign="top">
#         <row>
#          <entry align="center" nameend="1" namest="1" rowsep="1"/>
#         </row>
#         <row>
#          <entry>
#           Comparison of ‘Daligris’ to ‘Pinova’ (measurements given are approximate)
#          </entry>
#         </row>
#         <row>
#          <entry>
#           (Average of 20 fruits observed in comparative trials between ‘Daligris’ and ‘Pinova’
#          </entry>
#         </row>
#         <row>
#          <entry>
#           trees on M9 rootstock, similar crop load, same age)
#          </entry>
#         </row>
#        </tbody>
#       </tgroup>
#       <tgroup align="left" cols="5" colsep="0" rowsep="0">
#        <colspec align="center" colname="1" colwidth="35pt"/>
#        <colspec align="center" colname="2" colwidth="56pt"/>
#        <colspec align="center" colname="3" colwidth="56pt"/>
#        <colspec align="center" colname="4" colwidth="56pt"/>
#        <colspec align="center" colname="5" colwidth="56pt"/>
#        <tbody valign="top">
#         <row>
#          <entry>
#           Year
#          </entry>
#          <entry>
#           2005
#          </entry>
#          <entry>
#           2006
#          </entry>
#          <entry>
#           2007
#          </entry>
#          <entry>
#           2008
#          </entry>
#         </row>
#        </tbody>
#       </tgroup>
#       <tgroup align="left" cols="9" colsep="0" rowsep="0">
#        <colspec align="center" colname="1" colwidth="35pt"/>
#        <colspec align="center" colname="2" colwidth="28pt"/>
#        <colspec align="center" colname="3" colwidth="28pt"/>
#        <colspec align="center" colname="4" colwidth="28pt"/>
#        <colspec align="center" colname="5" colwidth="28pt"/>
#        <colspec align="center" colname="6" colwidth="28pt"/>
#        <colspec align="center" colname="7" colwidth="28pt"/>
#        <colspec align="center" colname="8" colwidth="28pt"/>
#        <colspec align="center" colname="9" colwidth="28pt"/>
#        <tbody valign="top">
#         <row>
#          <entry>
#           Variety
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Daligris
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Daligris
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Daligris
#          </entry>
#          <entry>
#           Pinova
#          </entry>
#          <entry>
#           Daligris
#          </entry>
#         </row>
#         <row>
#          <entry align="center" nameend="9" namest="1" rowsep="1"/>
#         </row>
#        </tbody>
#       </tgroup>
#       <tgroup align="left" cols="9" colsep="0" rowsep="0">
#        <colspec align="center" colname="1" colwidth="35pt"/>
#        <colspec align="char" char="." colname="2" colwidth="28pt"/>
#        <colspec align="char" char="." colname="3" colwidth="28pt"/>
#        <colspec align="char" char="." colname="4" colwidth="28pt"/>
#        <colspec align="char" char="." colname="5" colwidth="28pt"/>
#        <colspec align="char" char="." colname="6" colwidth="28pt"/>
#        <colspec align="char" char="." colname="7" colwidth="28pt"/>
#        <colspec align="char" char="." colname="8" colwidth="28pt"/>
#        <colspec align="char" char="." colname="9" colwidth="28pt"/>
#        <tbody valign="top">
#         <row>
#          <entry>
#           %
#          </entry>
#          <entry>
#           2
#          </entry>
#          <entry>
#           26
#          </entry>
#          <entry>
#           4
#          </entry>
#          <entry>
#           32
#          </entry>
#          <entry>
#           10
#          </entry>
#          <entry>
#           41
#          </entry>
#          <entry>
#           4
#          </entry>
#          <entry>
#           39
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Russet
#          </entry>
#         </row>
#         <row>
#          <entry>
#           % Over-
#          </entry>
#          <entry>
#           23
#          </entry>
#          <entry>
#           19
#          </entry>
#          <entry>
#           25
#          </entry>
#          <entry>
#           27
#          </entry>
#          <entry>
#           21
#          </entry>
#          <entry>
#           30
#          </entry>
#          <entry>
#           35
#          </entry>
#          <entry>
#           28
#          </entry>
#         </row>
#         <row>
#          <entry>
#           color
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Sugar
#          </entry>
#          <entry>
#           12
#          </entry>
#          <entry>
#           14.5
#          </entry>
#          <entry>
#           13.2
#          </entry>
#          <entry>
#           14.2
#          </entry>
#          <entry>
#           14.3
#          </entry>
#          <entry>
#           17.1
#          </entry>
#          <entry>
#           13.4
#          </entry>
#          <entry>
#           15.5
#          </entry>
#         </row>
#         <row>
#          <entry>
#           (° brix)
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Starch 6.4
#          </entry>
#          <entry>
#           7.1
#          </entry>
#          <entry>
#           6.6
#          </entry>
#          <entry>
#           7.0
#          </entry>
#          <entry>
#           8
#          </entry>
#          <entry>
#           7.2
#          </entry>
#          <entry>
#           7.3
#          </entry>
#          <entry>
#           5.9
#          </entry>
#         </row>
#         <row>
#          <entry>
#           test
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Harvest
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#          <entry>
#           Sept
#          </entry>
#         </row>
#         <row>
#          <entry>
#           Date
#          </entry>
#          <entry>
#           19
#           <sup>
#            th
#           </sup>
#          </entry>
#          <entry>
#           29
#           <sup>
#            th
#           </sup>
#          </entry>
#          <entry>
#           14
#           <sup>
#            th
#           </sup>
#          </entry>
#          <entry>
#           19
#           <sup>
#            th
#           </sup>
#          </entry>
#          <entry>
#           20
#           <sup>
#            th
#           </sup>
#          </entry>
#          <entry>
#           28
#           <sup>
#            th
#           </sup>
#          </entry>
#          <entry>
#           22
#           <sup>
#            nd
#           </sup>
#          </entry>
#          <entry>
#           29
#           <sup>
#            th
#           </sup>
#          </entry>
#         </row>
#         <row>
#          <entry align="center" nameend="9" namest="1" rowsep="1"/>
#         </row>
#        </tbody>
#       </tgroup>
#      </table>
#     </tables>
#    </p>
#   </description-of-drawings>
#   <?brief-description-of-drawings description="Brief Description of Drawings" end="tail"?>
#   <?DETDESC description="Detailed Description" end="lead"?>
#   <heading id="h-0008" level="1">
#    BRIEF DESCRIPTION OF THE PHOTOGRAPHS
#   </heading>
#   <p id="p-0017" num="0021">
#    <figref idref="DRAWINGS">
#     FIG. 1
#    </figref>
#    shows the fruit of ‘Daligris’ after harvest;
#   </p>
#   <p id="p-0018" num="0022">
#    <figref idref="DRAWINGS">
#     FIG. 2
#    </figref>
#    shows ‘Daligris’ in bloom in an orchard;
#   </p>
#   <p id="p-0019" num="0023">
#    <figref idref="DRAWINGS">
#     FIG. 3
#    </figref>
#    shows ‘Daligris’ fruit on the tree; and
#   </p>
#   <p id="p-0020" num="0024">
#    <figref idref="DRAWINGS">
#     FIG. 4
#    </figref>
#    shows ‘Daligris’ fruit as compared to ‘Pinova’ fruit.
#   </p>
#   <heading id="h-0009" level="1">
#    DETAILED BOTANICAL DESCRIPTION OF THE VARIETY
#   </heading>
#   <p id="p-0021" num="0025">
#    The following detailed botanical description is based on general observations made of the mother tree from 1998 to 2003 and on second and third generation trees from 2002 to 2008. Quantified measurements of the trees, flowers and leaves are based on observations of three year old trees grown on M9 rootstock in a high density planting in the temperate climate of the Loire Valley, France. All colors are described according to The Royal Horticultural Society Colour Chart. It should be understood that the characteristics described will vary somewhat depending upon cultural practices and climatic conditions, and will vary with location and season. The measurements of any individual plant, or any group of plants, of the new variety may vary from the stated average.
#    <ul id="ul0005" list-style="none">
#     <li id="ul0005-0001" num="0026">
#      Tree:
#      <ul id="ul0006" list-style="none">
#       <li id="ul0006-0001" num="0000">
#        <ul id="ul0007" list-style="none">
#         <li id="ul0007-0001" num="0027">
#          <i>
#           Vigor.—
#          </i>
#          Weak to medium (less than ‘Pinova’).
#         </li>
#         <li id="ul0007-0002" num="0028">
#          <i>
#           Type.—
#          </i>
#          Spur to ramified (a little less ramified than ‘Pinova’).
#         </li>
#         <li id="ul0007-0003" num="0029">
#          <i>
#           Habit.—
#          </i>
#          Upright.
#         </li>
#         <li id="ul0007-0004" num="0030">
#          <i>
#           Height.—
#          </i>
#          Low to medium (191 cm).
#         </li>
#         <li id="ul0007-0005" num="0031">
#          <i>
#           Diameter.—
#          </i>
#          Medium (101 cm).
#         </li>
#         <li id="ul0007-0006" num="0032">
#          <i>
#           Trunk diameter
#          </i>
#          (
#          <i>
#           at
#          </i>
#          30
#          <i>
#           cm above the graft union
#          </i>
#          ).—Medium (35 mm).
#         </li>
#         <li id="ul0007-0007" num="0033">
#          <i>
#           Bark texture.—
#          </i>
#          Smooth to medium.
#         </li>
#         <li id="ul0007-0008" num="0034">
#          <i>
#           Bark coloration.—
#          </i>
#          Grey 201C.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0002" num="0035">
#      Branch (fruiting branches located at around 1 m above the graft union):
#      <ul id="ul0008" list-style="none">
#       <li id="ul0008-0001" num="0000">
#        <ul id="ul0009" list-style="none">
#         <li id="ul0009-0001" num="0036">
#          <i>
#           Length.—
#          </i>
#          Short to medium (avg. 41 cm).
#         </li>
#         <li id="ul0009-0002" num="0037">
#          <i>
#           Diameter.—
#          </i>
#          Medium (avg. 19 mm).
#         </li>
#         <li id="ul0009-0003" num="0038">
#          <i>
#           Crotch angle.—
#          </i>
#          60° to 80°.
#         </li>
#         <li id="ul0009-0004" num="0039">
#          <i>
#           Bark color.—
#          </i>
#          Brown 200B.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0003" num="0040">
#      One year old shoot:
#      <ul id="ul0010" list-style="none">
#       <li id="ul0010-0001" num="0000">
#        <ul id="ul0011" list-style="none">
#         <li id="ul0011-0001" num="0041">
#          <i>
#           Length.—
#          </i>
#          Medium (avg. 16.3 cm).
#         </li>
#         <li id="ul0011-0002" num="0042">
#          <i>
#           Color.—
#          </i>
#          Brown 200B.
#         </li>
#         <li id="ul0011-0003" num="0043">
#          <i>
#           Pubescence
#          </i>
#          (
#          <i>
#           on upper half of the shoot
#          </i>
#          ).—Medium.
#         </li>
#         <li id="ul0011-0004" num="0044">
#          <i>
#           Thickness.—
#          </i>
#          Medium thick (avg. 6.4 mm).
#         </li>
#         <li id="ul0011-0005" num="0045">
#          <i>
#           Internode length.—
#          </i>
#          Short (avg. 10 mm).
#         </li>
#         <li id="ul0011-0006" num="0046">
#          <i>
#           Number of lenticels.—
#          </i>
#          Medium (6 lenticels per cm
#          <sup>
#           2
#          </sup>
#          ).
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0004" num="0047">
#      Winter hardiness:
#      <ul id="ul0012" list-style="none">
#       <li id="ul0012-0001" num="0000">
#        <ul id="ul0013" list-style="none">
#         <li id="ul0013-0001" num="0048">
#          <i>
#           Hardiness.—
#          </i>
#          Similar to ‘Pinova’.
#         </li>
#         <li id="ul0013-0002" num="0049">
#          <i>
#           Chilling requirement.—
#          </i>
#          Similar to ‘Pinova’.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0005" num="0050">
#      Flower buds:
#      <ul id="ul0014" list-style="none">
#       <li id="ul0014-0001" num="0000">
#        <ul id="ul0015" list-style="none">
#         <li id="ul0015-0001" num="0051">
#          <i>
#           Quantity per spur.—
#          </i>
#          2 to 3.
#         </li>
#         <li id="ul0015-0002" num="0052">
#          <i>
#           Shape.—
#          </i>
#          Conical.
#         </li>
#         <li id="ul0015-0003" num="0053">
#          <i>
#           Length.—
#          </i>
#          Medium (avg. 12 mm).
#         </li>
#         <li id="ul0015-0004" num="0054">
#          <i>
#           Diameter.—
#          </i>
#          Medium (avg. 8 mm).
#         </li>
#         <li id="ul0015-0005" num="0055">
#          <i>
#           Color.—
#          </i>
#          Red purple 61A.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0006" num="0056">
#      Flowers:
#      <ul id="ul0016" list-style="none">
#       <li id="ul0016-0001" num="0000">
#        <ul id="ul0017" list-style="none">
#         <li id="ul0017-0001" num="0057">
#          <i>
#           Color
#          </i>
#          (
#          <i>
#           balloon stage
#          </i>
#          ).—Purple 77C.
#         </li>
#         <li id="ul0017-0002" num="0058">
#          <i>
#           Diameter of open flower.—
#          </i>
#          Large (avg. 3.6 cm).
#         </li>
#         <li id="ul0017-0003" num="0059">
#          <i>
#           Relative position of petal margin.—
#          </i>
#          Not touching.
#         </li>
#         <li id="ul0017-0004" num="0060">
#          <i>
#           Number per cluster.—
#          </i>
#          5 to 7.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0007" num="0061">
#      Bloom date:
#      <ul id="ul0018" list-style="none">
#       <li id="ul0018-0001" num="0000">
#        <ul id="ul0019" list-style="none">
#         <li id="ul0019-0001" num="0062">
#          <i>
#           Date of first bloom.—
#          </i>
#          April 15 in Angers, France (comparable to ‘Pinova’).
#         </li>
#         <li id="ul0019-0002" num="0063">
#          <i>
#           Date of full bloom.—
#          </i>
#          April 20 in Angers, France (comparable to ‘Pinova’).
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0008" num="0064">
#      Petals:
#      <ul id="ul0020" list-style="none">
#       <li id="ul0020-0001" num="0000">
#        <ul id="ul0021" list-style="none">
#         <li id="ul0021-0001" num="0065">
#          <i>
#           Number per flower.—
#          </i>
#          5.
#         </li>
#         <li id="ul0021-0002" num="0066">
#          <i>
#           Shape.—
#          </i>
#          Oval.
#         </li>
#         <li id="ul0021-0003" num="0067">
#          <i>
#           Length.—
#          </i>
#          Medium long (avg. 20 mm).
#         </li>
#         <li id="ul0021-0004" num="0068">
#          <i>
#           Width.—
#          </i>
#          Medium wide (avg. 15 mm).
#         </li>
#         <li id="ul0021-0005" num="0069">
#          <i>
#           Apex.—
#          </i>
#          Round.
#         </li>
#         <li id="ul0021-0006" num="0070">
#          <i>
#           Base.—
#          </i>
#          Pointed.
#         </li>
#         <li id="ul0021-0007" num="0071">
#          <i>
#           Margin.—
#          </i>
#          Smooth.
#         </li>
#         <li id="ul0021-0008" num="0072">
#          <i>
#           Coloration of upper surface.—
#          </i>
#          White 155B with purple 76B included herein.
#         </li>
#         <li id="ul0021-0009" num="0073">
#          <i>
#           Coloration of lower surface.—
#          </i>
#          Purple 77D.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0009" num="0074">
#      Pistils:
#      <ul id="ul0022" list-style="none">
#       <li id="ul0022-0001" num="0000">
#        <ul id="ul0023" list-style="none">
#         <li id="ul0023-0001" num="0075">
#          <i>
#           Size.—
#          </i>
#          Long (13 mm).
#         </li>
#         <li id="ul0023-0002" num="0076">
#          <i>
#           Color.—
#          </i>
#          Yellow green 145D.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0010" num="0077">
#      Anthers:
#      <ul id="ul0024" list-style="none">
#       <li id="ul0024-0001" num="0000">
#        <ul id="ul0025" list-style="none">
#         <li id="ul0025-0001" num="0078">
#          <i>
#           Quantity.—
#          </i>
#          Numerous (avg. 17 per flower).
#         </li>
#         <li id="ul0025-0002" num="0079">
#          <i>
#           Size.—
#          </i>
#          Medium (avg. 2 mm).
#         </li>
#         <li id="ul0025-0003" num="0080">
#          <i>
#           Presence of pollen.—
#          </i>
#          Present.
#         </li>
#         <li id="ul0025-0004" num="0081">
#          <i>
#           Color of pollen.—
#          </i>
#          Yellow 4C.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0011" num="0082">
#      Stigma:
#      <ul id="ul0026" list-style="none">
#       <li id="ul0026-0001" num="0000">
#        <ul id="ul0027" list-style="none">
#         <li id="ul0027-0001" num="0083">
#          <i>
#           Size.—
#          </i>
#          Small to medium (avg. 0.5 mm).
#         </li>
#         <li id="ul0027-0002" num="0084">
#          <i>
#           Color.—
#          </i>
#          Pale yellow 9C.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0012" num="0085">
#      Style:
#      <ul id="ul0028" list-style="none">
#       <li id="ul0028-0001" num="0000">
#        <ul id="ul0029" list-style="none">
#         <li id="ul0029-0001" num="0086">
#          <i>
#           Size.—
#          </i>
#          Medium to long (avg. 9 mm).
#         </li>
#         <li id="ul0029-0002" num="0087">
#          <i>
#           Color.—
#          </i>
#          Yellow green N144D.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0013" num="0088">
#      Ovary:
#      <ul id="ul0030" list-style="none">
#       <li id="ul0030-0001" num="0000">
#        <ul id="ul0031" list-style="none">
#         <li id="ul0031-0001" num="0089">
#          <i>
#           Size.—
#          </i>
#          Medium (avg. 2 mm).
#         </li>
#         <li id="ul0031-0002" num="0090">
#          <i>
#           Color.—
#          </i>
#          Green 134B.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0014" num="0091">
#      Pedicel:
#      <ul id="ul0032" list-style="none">
#       <li id="ul0032-0001" num="0000">
#        <ul id="ul0033" list-style="none">
#         <li id="ul0033-0001" num="0092">
#          <i>
#           Length.—
#          </i>
#          Medium (avg. 2 cm).
#         </li>
#         <li id="ul0033-0002" num="0093">
#          <i>
#           Diameter.—
#          </i>
#          Thin (avg. 1.4 mm).
#         </li>
#         <li id="ul0033-0003" num="0094">
#          <i>
#           Color.—
#          </i>
#          Green 142C.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0015" num="0095">
#      Sepals:
#      <ul id="ul0034" list-style="none">
#       <li id="ul0034-0001" num="0000">
#        <ul id="ul0035" list-style="none">
#         <li id="ul0035-0001" num="0096">
#          <i>
#           Quantity.—
#          </i>
#          5.
#         </li>
#         <li id="ul0035-0002" num="0097">
#          <i>
#           Coloration.—
#          </i>
#          Green 143C.
#         </li>
#         <li id="ul0035-0003" num="0098">
#          <i>
#           Shape.—
#          </i>
#          Conical pointed.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0016" num="0099">
#      Leaves:
#      <ul id="ul0036" list-style="none">
#       <li id="ul0036-0001" num="0000">
#        <ul id="ul0037" list-style="none">
#         <li id="ul0037-0001" num="0100">
#          <i>
#           Shape.—
#          </i>
#          Oblanceolate.
#         </li>
#         <li id="ul0037-0002" num="0101">
#          <i>
#           Length
#          </i>
#          (
#          <i>
#           petiole not included
#          </i>
#          ).—Long (avg. 11.1 cm).
#         </li>
#         <li id="ul0037-0003" num="0102">
#          <i>
#           Width.—
#          </i>
#          Medium-wide (avg. 5.9 cm).
#         </li>
#         <li id="ul0037-0004" num="0103">
#          <i>
#           Length/width ratio.—
#          </i>
#          Medium (2).
#         </li>
#         <li id="ul0037-0005" num="0104">
#          <i>
#           Blade margin.—
#          </i>
#          Crenate.
#         </li>
#         <li id="ul0037-0006" num="0105">
#          <i>
#           Apex.—
#          </i>
#          Acuminate.
#         </li>
#         <li id="ul0037-0007" num="0106">
#          <i>
#           Base shape.—
#          </i>
#          Oblique.
#         </li>
#         <li id="ul0037-0008" num="0107">
#          <i>
#           Color of upper surface.—
#          </i>
#          Green 143A (in early summer).
#         </li>
#         <li id="ul0037-0009" num="0108">
#          <i>
#           Color of lower surface.—
#          </i>
#          Green 143C (in early summer).
#         </li>
#         <li id="ul0037-0010" num="0109">
#          <i>
#           Attitude in relation to shoot.—
#          </i>
#          Upward.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0017" num="0110">
#      Petiole:
#      <ul id="ul0038" list-style="none">
#       <li id="ul0038-0001" num="0000">
#        <ul id="ul0039" list-style="none">
#         <li id="ul0039-0001" num="0111">
#          <i>
#           Length.—
#          </i>
#          Long (avg. 3.5 cm).
#         </li>
#         <li id="ul0039-0002" num="0112">
#          <i>
#           Diameter.—
#          </i>
#          Thick (avg. 1.6 mm).
#         </li>
#         <li id="ul0039-0003" num="0113">
#          <i>
#           Coloration.—
#          </i>
#          Yellow green 145B.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0018" num="0114">
#      Fruit:
#      <ul id="ul0040" list-style="none">
#       <li id="ul0040-0001" num="0000">
#        <ul id="ul0041" list-style="none">
#         <li id="ul0041-0001" num="0115">
#          <i>
#           Quantity per cluster.—
#          </i>
#          3 to 4.
#         </li>
#         <li id="ul0041-0002" num="0116">
#          <i>
#           Size.—
#          </i>
#          Medium large (avg. 71 mm).
#         </li>
#         <li id="ul0041-0003" num="0117">
#          <i>
#           Weight.—
#          </i>
#          Medium (avg. 166 g).
#         </li>
#         <li id="ul0041-0004" num="0118">
#          <i>
#           Ratio of height to width.—
#          </i>
#          Small to medium (0.9).
#         </li>
#         <li id="ul0041-0005" num="0119">
#          <i>
#           General shape in profile.—
#          </i>
#          Conical to truncate conical.
#         </li>
#         <li id="ul0041-0006" num="0120">
#          <i>
#           Position of maximum diameter.—
#          </i>
#          Top third of the fruit.
#         </li>
#         <li id="ul0041-0007" num="0121">
#          <i>
#           Ribbing.—
#          </i>
#          Absent.
#         </li>
#         <li id="ul0041-0008" num="0122">
#          <i>
#           Aperture of eye.—
#          </i>
#          Closed.
#         </li>
#         <li id="ul0041-0009" num="0123">
#          <i>
#           Size of eye.—
#          </i>
#          Large (avg. 9.5 mm).
#         </li>
#         <li id="ul0041-0010" num="0124">
#          <i>
#           Length of sepal.—
#          </i>
#          Long (avg. 7.7 mm).
#         </li>
#         <li id="ul0041-0011" num="0125">
#          <i>
#           Depth of eye basin.—
#          </i>
#          Deep (avg. 11.5 mm).
#         </li>
#         <li id="ul0041-0012" num="0126">
#          <i>
#           Width of eye basin.—
#          </i>
#          Medium (avg. 29 mm).
#         </li>
#         <li id="ul0041-0013" num="0127">
#          <i>
#           Length of stalk.—
#          </i>
#          Medium long (avg. 29 cm).
#         </li>
#         <li id="ul0041-0014" num="0128">
#          <i>
#           Thickness of stalk.—
#          </i>
#          Medium (avg. 2.1 mm).
#         </li>
#         <li id="ul0041-0015" num="0129">
#          <i>
#           Width of stalk cavity.—
#          </i>
#          Medium (avg. 33 mm).
#         </li>
#         <li id="ul0041-0016" num="0130">
#          <i>
#           Depth of stalk cavity.—
#          </i>
#          Flat (avg. 7 mm).
#         </li>
#         <li id="ul0041-0017" num="0131">
#          <i>
#           Size of lenticels.—
#          </i>
#          Very large (avg. 1.2 mm).
#         </li>
#         <li id="ul0041-0018" num="0132">
#          <i>
#           Number of lenticels.—
#          </i>
#          Medium.
#         </li>
#         <li id="ul0041-0019" num="0133">
#          <i>
#           Bloom of skin.—
#          </i>
#          Absent or very weak.
#         </li>
#         <li id="ul0041-0020" num="0134">
#          <i>
#           Greasiness of skin.—
#          </i>
#          Weak to moderate.
#         </li>
#         <li id="ul0041-0021" num="0135">
#          <i>
#           Background color of skin.—
#          </i>
#          Yellow 13C.
#         </li>
#         <li id="ul0041-0022" num="0136">
#          <i>
#           Amount of over color.—
#          </i>
#          Low (10% to 40%).
#         </li>
#         <li id="ul0041-0023" num="0137">
#          <i>
#           Over color of skin.—
#          </i>
#          Red stripes 41A on red orange 42A.
#         </li>
#         <li id="ul0041-0024" num="0138">
#          <i>
#           Intensity of over color.—
#          </i>
#          Light to medium.
#         </li>
#         <li id="ul0041-0025" num="0139">
#          <i>
#           Amount of russet around stalk cavity.—
#          </i>
#          Very high.
#         </li>
#         <li id="ul0041-0026" num="0140">
#          <i>
#           Amount of russet on cheeks.—
#          </i>
#          Medium to high.
#         </li>
#         <li id="ul0041-0027" num="0141">
#          <i>
#           Area of russet around eye basin.—
#          </i>
#          Low.
#         </li>
#         <li id="ul0041-0028" num="0142">
#          <i>
#           Relative area of fruit covered with russeting.—
#          </i>
#          Medium to high (20% to 40%).
#         </li>
#         <li id="ul0041-0029" num="0143">
#          <i>
#           Flesh texture.—
#          </i>
#          Firm.
#         </li>
#         <li id="ul0041-0030" num="0144">
#          <i>
#           Aroma.—
#          </i>
#          Very intense.
#         </li>
#         <li id="ul0041-0031" num="0145">
#          <i>
#           Flavor.—
#          </i>
#          Sweet with an aniseed flavor.
#         </li>
#         <li id="ul0041-0032" num="0146">
#          <i>
#           Juiciness.—
#          </i>
#          Medium.
#         </li>
#         <li id="ul0041-0033" num="0147">
#          <i>
#           Brix.—
#          </i>
#          Very high (2° brix higher than ‘Pinova’).
#         </li>
#         <li id="ul0041-0034" num="0148">
#          <i>
#           Flesh coloration.—
#          </i>
#          Yellow 11D.
#         </li>
#         <li id="ul0041-0035" num="0149">
#          <i>
#           Stem coloration.—
#          </i>
#          Grey brown N199D.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0019" num="0150">
#      Seeds:
#      <ul id="ul0042" list-style="none">
#       <li id="ul0042-0001" num="0000">
#        <ul id="ul0043" list-style="none">
#         <li id="ul0043-0001" num="0151">
#          <i>
#           Quantity per fruit.—
#          </i>
#          5 on average.
#         </li>
#         <li id="ul0043-0002" num="0152">
#          <i>
#           Shape.—
#          </i>
#          Truncate ovoid.
#         </li>
#         <li id="ul0043-0003" num="0153">
#          <i>
#           Coloration.—
#          </i>
#          Brown 200D.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#     <li id="ul0005-0020" num="0154">
#      Harvest:
#      <ul id="ul0044" list-style="none">
#       <li id="ul0044-0001" num="0000">
#        <ul id="ul0045" list-style="none">
#         <li id="ul0045-0001" num="0155">
#          <i>
#           Beginning of harvest.—
#          </i>
#          Last week of September (1 week after the beginning of ‘Pinova's’ harvest).
#         </li>
#         <li id="ul0045-0002" num="0156">
#          <i>
#           Harvest window.—
#          </i>
#          3 weeks.
#         </li>
#         <li id="ul0045-0003" num="0157">
#          <i>
#           Number of picks.—
#          </i>
#          Three picks.
#         </li>
#         <li id="ul0045-0004" num="0158">
#          <i>
#           Amount of fruit produced per tree per harvest.—
#          </i>
#          60 fruits on third leaf tree.
#         </li>
#         <li id="ul0045-0005" num="0159">
#          <i>
#           Time for eating maturity.—
#          </i>
#          Late.
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </li>
#    </ul>
#   </p>
#   <?DETDESC description="Detailed Description" end="tail"?>
#  </description>
#  <us-claim-statement>
#   I claim:
#  </us-claim-statement>
#  <claims id="claims">
#   <claim id="CLM-00001" num="00001">
#    <claim-text>
#     1. A new and distinct apple tree substantially as described and illustrated herein.
#    </claim-text>
#   </claim>
#  </claims>
# </us-patent-grant>

# %% [markdown]
# The XML structure within specific tags is used to extract the required information for this analysis. The function `show_tree` is used to examine the specific structure of the XML of interest.

# %% [markdown]
# #### XML Structure - Citations
# The structure of the xml tree within the 'citation' tag is used to identify cited patents. A patent may cite more than one other patent.
#
# Creation of the citation network uses the `<doc-number>` tag nested under the `<citation>` tag.

# %%
# Out:
# <citation>
# <patcit num="00001">
# <document-id>
# <country>US</country>
# <doc-number>PP17672</doc-number>
# <kind>P3</kind>
# <name>Hofmann</name>
# <date>20070500</date>
# </document-id>
# </patcit>
# <category>cited by examiner</category>
# <classification-national><country>US</country><main-classification>PLT161</main-classification></classification-national>
# </citation>

# %% [markdown]
# #### XML Structure - Publication Reference
# The publication reference contains the document number for the patent.
#
# The tag of interest is the `<doc-number>` tag nested within the `<publication-reference>` tag.

# %%
# Out:
# <publication-reference>
# <document-id>
# <country>US</country>
# <doc-number>PP021722</doc-number>
# <kind>P3</kind>
# <date>20110222</date>
# </document-id>
# </publication-reference>

# %% [markdown]
# #### XML Structure - Classifications
# There are multple parts to the classification: `<classification-level>`, `<section>`, `<class>`, `<subclass>`, `<main-group>` and `<subgroup>`.  These tags are all nested under the `<classifications-ipcr>` tag.

# %%
# Out:
# <classifications-ipcr>
# <classification-ipcr>
# <ipc-version-indicator><date>20060101</date></ipc-version-indicator>
# <classification-level>A</classification-level>
# <section>A</section>
# <class>01</class>
# <subclass>H</subclass>
# <main-group>5</main-group>
# <subgroup>00</subgroup>
# <symbol-position>F</symbol-position>
# <classification-value>I</classification-value>
# <action-date><date>20110222</date></action-date>
# <generating-office><country>US</country></generating-office>
# <classification-status>B</classification-status>
# <classification-data-source>H</classification-data-source>
# </classification-ipcr>
# </classifications-ipcr>

# %% [markdown]
# ## 4. Parsing XML and Extracting all the required information
#
# The `Patent` class is used to extract the required information for citations, ipc_code and abstracts. The class is instantiated with the xml text associated with a patent, converted to a `BeautifulSoup` object, and then uses the BeautifulSoup methods `find` and `find_all` to extract the required information.

# %% [markdown]
# ### 4.1 Extracting the Citation Network, Hierarchical IPC Code, and Creation of  a List of Abstracts
# For each patent in the document list (`doc_list`), the xml text is passed to the class object, and the required information retrieved. In the case of citations and classifications, this information is passed straight to a file. For abstracts, a list containing all paragraphs associated with each abstract is created. Additionally, a list of patent IDs is also created.

# %%
# Out:
# 2500

# %% [markdown]
# ### 4.2 Identify number of patent citations:
# The citation network can be described by counting the number of times a patent is cited. The file `cited.txt` contains a list of all patents cited, and the number of times they have been cited, in the format `patentID: # of times cited`

# %%
# Out:
# Total Citations:  47041
# Unique Patents cited:  40728
# 47041

# %% [markdown]
# An alternate way of exploring the citation network is to count how many other patents are cited by each of the 2500 patents.
# The number of patent citations cited by each of the 2500 patents is calculated from the previously created `citations.txt` file.
# `Cited_alt.txt` contains the total count of patents cited by each of the 2500 patents in the patent list, in the format `PatentID: # of patents cited`.

# %%
# Out:
# 2500
# ['PP021722:3',
#  'RE042159:11',
#  'RE042170:21',
#  '07891018:13',
#  '07891019:8',
#  '07891020:20',
#  '07891021:7',
#  '07891023:34',
#  '07891025:10',
#  '07891026:26',
#  '07891027:8',
#  '07891029:22',
#  '07891030:6',
#  '07891032:1',
#  '07891033:5',
#  '07891034:18',
#  '07891036:37',
#  '07891037:4',
#  '07891038:20',
#  '07891039:12',
#  '07891041:9',
#  '07891044:40',
#  '07891053:20',
#  '07891055:16',
#  '07891056:18',
#  '07891057:17',
#  '07891058:31',
#  '07891059:21',
#  '07891060:8',
#  '07891063:18',
#  '07891067:13',
#  '07891070:13',
#  '07891071:28',
#  '07891076:49',
#  '07891078:8',
#  '07891082:13',
#  '07891083:2',
#  '07891084:4',
#  '07891086:8',
#  '07891087:8',
#  '07891097:20',
#  '07891098:9',
#  '07891104:3',
#  '07891107:10',
#  '07891111:10',
#  '07891114:108',
#  '07891115:13',
#  '07891116:11',
#  '07891117:15',
#  '07891118:11',
#  '07891121:23',
#  '07891123:9',
#  '07891129:16',
#  '07891133:24',
#  '07891136:27',
#  '07891139:15',
#  '07891140:13',
#  '07891141:17',
#  '07891146:33',
#  '07891148:89',
#  '07891152:23',
#  '07891158:40',
#  '07891159:31',
#  '07891160:28',
#  '07891161:21',
#  '07891162:27',
#  '07891163:18',
#  '07891165:9',
#  '07891166:23',
#  '07891167:10',
#  '07891169:11',
#  '07891170:12',
#  '07891173:11',
#  '07891177:22',
#  '07891178:28',
#  '07891183:19',
#  '07891188:8',
#  '07891192:9',
#  '07891198:113',
#  '07891199:9',
#  '07891201:15',
#  '07891203:17',
#  '07891206:13',
#  '07891210:14',
#  '07891219:26',
#  '07891221:16',
#  '07891231:7',
#  '07891234:1',
#  '07891239:10',
#  '07891242:51',
#  '07891248:17',
#  '07891249:11',
#  '07891252:14',
#  '07891255:15',
#  '07891259:12',
#  '07891260:10',
#  '07891262:7',
#  '07891266:10',
#  '07891268:5',
#  '07891269:7',
#  '07891271:15',
#  '07891272:9',
#  '07891273:7',
#  '07891284:34',
#  '07891285:6',
#  '07891292:8',
#  '07891297:16',
#  '07891301:6',
#  '07891302:20',
#  '07891303:24',
#  '07891305:29',
#  '07891306:31',
#  '07891308:4',
#  '07891309:10',
#  '07891313:7',
#  '07891317:24',
#  '07891318:22',
#  '07891321:17',
#  '07891323:9',
#  '07891326:7',
#  '07891327:11',
#  '07891328:2',
#  '07891329:6',
#  '07891330:4',
#  '07891333:4',
#  '07891334:59',
#  '07891336:23',
#  '07891346:13',
#  '07891347:6',
#  '07891348:29',
#  '07891352:9',
#  '07891357:9',
#  '07891358:15',
#  '07891359:31',
#  '07891366:7',
#  '07891367:37',
#  '07891369:102',
#  '07891372:21',
#  '07891373:23',
#  '07891374:21',
#  '07891378:10',
#  '07891382:17',
#  '07891386:2',
#  '07891388:10',
#  '07891389:24',
#  '07891390:13',
#  '07891398:33',
#  '07891401:31',
#  '07891403:14',
#  '07891413:22',
#  '07891414:11',
#  '07891419:4',
#  '07891425:10',
#  '07891434:5',
#  '07891436:27',
#  '07891438:14',
#  '07891441:18',
#  '07891442:5',
#  '07891443:11',
#  '07891445:10',
#  '07891448:30',
#  '07891450:61',
#  '07891455:41',
#  '07891460:21',
#  '07891465:5',
#  '07891466:22',
#  '07891467:14',
#  '07891471:9',
#  '07891473:11',
#  '07891477:17',
#  '07891480:16',
#  '07891481:23',
#  '07891482:14',
#  '07891484:32',
#  '07891487:24',
#  '07891490:3',
#  '07891492:25',
#  '07891493:71',
#  '07891496:18',
#  '07891502:12',
#  '07891504:19',
#  '07891507:52',
#  '07891508:50',
#  '07891512:29',
#  '07891513:13',
#  '07891520:11',
#  '07891521:12',
#  '07891524:22',
#  '07891531:14',
#  '07891532:371',
#  '07891533:117',
#  '07891534:243',
#  '07891535:5',
#  '07891544:3',
#  '07891548:34',
#  '07891550:4',
#  '07891553:4',
#  '07891556:5',
#  '07891561:11',
#  '07891564:13',
#  '07891565:28',
#  '07891570:12',
#  '07891578:29',
#  '07891579:8',
#  '07891580:29',
#  '07891582:8',
#  '07891583:4',
#  '07891589:16',
#  '07891591:10',
#  '07891592:3',
#  '07891593:19',
#  '07891594:11',
#  '07891596:13',
#  '07891598:14',
#  '07891600:12',
#  '07891602:5',
#  '07891607:23',
#  '07891609:41',
#  '07891612:12',
#  '07891613:14',
#  '07891614:41',
#  '07891616:3',
#  '07891617:15',
#  '07891619:14',
#  '07891621:21',
#  '07891623:13',
#  '07891628:11',
#  '07891629:10',
#  '07891631:10',
#  '07891632:14',
#  '07891633:17',
#  '07891638:5',
#  '07891639:12',
#  '07891642:17',
#  '07891643:10',
#  '07891645:19',
#  '07891647:9',
#  '07891653:6',
#  '07891654:4',
#  '07891655:42',
#  '07891656:9',
#  '07891659:15',
#  '07891661:8',
#  '07891664:19',
#  '07891665:11',
#  '07891667:18',
#  '07891668:28',
#  '07891670:62',
#  '07891676:48',
#  '07891677:29',
#  '07891678:15',
#  '07891680:12',
#  '07891685:12',
#  '07891686:20',
#  '07891687:11',
#  '07891688:16',
#  '07891689:9',
#  '07891691:17',
#  '07891692:12',
#  '07891693:11',
#  '07891698:8',
#  '07891700:16',
#  '07891702:17',
#  '07891703:14',
#  '07891706:8',
#  '07891707:28',
#  '07891709:15',
#  '07891710:36',
#  '07891714:5',
#  '07891715:19',
#  '07891717:16',
#  '07891719:52',
#  '07891720:3',
#  '07891721:9',
#  '07891722:12',
#  '07891724:14',
#  '07891725:20',
#  '07891727:9',
#  '07891728:38',
#  '07891731:18',
#  '07891732:22',
#  '07891737:13',
#  '07891739:7',
#  '07891741:32',
#  '07891744:24',
#  '07891746:23',
#  '07891748:15',
#  '07891749:18',
#  '07891750:13',
#  '07891752:7',
#  '07891757:9',
#  '07891760:22',
#  '07891761:32',
#  '07891763:13',
#  '07891766:16',
#  '07891768:25',
#  '07891769:18',
#  '07891773:42',
#  '07891775:70',
#  '07891780:7',
#  '07891783:2',
#  '07891784:3',
#  '07891785:5',
#  '07891786:7',
#  '07891787:16',
#  '07891789:28',
#  '07891790:3',
#  '07891791:59',
#  '07891793:2',
#  '07891794:14',
#  '07891799:36',
#  '07891800:8',
#  '07891804:12',
#  '07891806:7',
#  '07891807:12',
#  '07891813:1',
#  '07891817:8',
#  '07891819:5',
#  '07891820:10',
#  '07891824:11',
#  '07891829:22',
#  '07891833:14',
#  '07891836:18',
#  '07891840:7',
#  '07891842:4',
#  '07891845:2',
#  '07891847:11',
#  '07891853:5',
#  '07891855:2',
#  '07891857:4',
#  '07891859:6',
#  '07891862:10',
#  '07891868:18',
#  '07891877:4',
#  '07891882:27',
#  '07891884:6',
#  '07891887:5',
#  '07891888:10',
#  '07891900:11',
#  '07891902:26',
#  '07891904:9',
#  '07891905:5',
#  '07891912:3',
#  '07891914:19',
#  '07891921:2',
#  '07891923:11',
#  '07891925:19',
#  '07891926:26',
#  '07891930:18',
#  '07891932:5',
#  '07891935:8',
#  '07891936:20',
#  '07891940:34',
#  '07891945:7',
#  '07891946:4',
#  '07891947:17',
#  '07891958:6',
#  '07891960:30',
#  '07891968:14',
#  '07891977:9',
#  '07891979:7',
#  '07891981:4',
#  '07891984:3',
#  '07891985:7',
#  '07891986:7',
#  '07891990:22',
#  '07891991:12',
#  '07891993:14',
#  '07891996:3',
#  '07891998:10',
#  '07892000:5',
#  '07892003:10',
#  '07892006:5',
#  '07892008:12',
#  '07892013:14',
#  '07892016:12',
#  '07892017:31',
#  '07892018:33',
#  '07892019:7',
#  '07892020:17',
#  '07892021:13',
#  '07892023:5',
#  '07892024:5',
#  '07892025:26',
#  '07892027:8',
#  '07892029:32',
#  '07892030:5',
#  '07892033:5',
#  '07892037:20',
#  '07892038:12',
#  '07892039:13',
#  '07892041:14',
#  '07892042:21',
#  '07892043:1',
#  '07892047:19',
#  '07892049:46',
#  '07892050:26',
#  '07892052:7',
#  '07892057:11',
#  '07892058:3',
#  '07892060:21',
#  '07892062:17',
#  '07892064:17',
#  '07892067:34',
#  '07892069:9',
#  '07892070:8',
#  '07892072:5',
#  '07892075:20',
#  '07892077:30',
#  '07892080:4',
#  '07892082:5',
#  '07892083:5',
#  '07892084:8',
#  '07892085:10',
#  '07892086:23',
#  '07892087:55',
#  '07892099:4',
#  '07892100:18',
#  '07892102:19',
#  '07892103:6',
#  '07892104:5',
#  '07892106:19',
#  '07892107:27',
#  '07892108:5',
#  '07892110:14',
#  '07892112:7',
#  '07892113:13',
#  '07892115:25',
#  '07892116:11',
#  '07892120:46',
#  '07892123:9',
#  '07892124:11',
#  '07892128:20',
#  '07892131:22',
#  '07892135:11',
#  '07892136:1',
#  '07892138:26',
#  '07892149:6',
#  '07892150:18',
#  '07892152:41',
#  '07892156:11',
#  '07892158:17',
#  '07892159:21',
#  '07892161:12',
#  '07892163:253',
#  '07892164:23',
#  '07892170:68',
#  '07892193:10',
#  '07892204:4',
#  '07892213:30',
#  '07892218:17',
#  '07892223:25',
#  '07892225:17',
#  '07892232:18',
#  '07892237:6',
#  '07892242:3',
#  '07892244:13',
#  '07892245:25',
#  '07892252:38',
#  '07892258:2',
#  '07892263:78',
#  '07892266:48',
#  '07892268:10',
#  '07892278:2',
#  '07892285:12',
#  '07892287:139',
#  '07892300:3',
#  '07892320:4',
#  '07892321:13',
#  '07892330:11',
#  '07892332:176',
#  '07892337:47',
#  '07892338:16',
#  '07892341:1',
#  '07892343:14',
#  '07892355:4',
#  '07892363:1',
#  '07892374:2',
#  '07892377:2',
#  '07892380:19',
#  '07892381:19',
#  '07892384:26',
#  '07892389:11',
#  '07892405:5',
#  '07892412:8',
#  '07892421:20',
#  '07892422:69',
#  '07892425:10',
#  '07892428:22',
#  '07892432:3',
#  '07892437:8',
#  '07892440:8',
#  '07892443:10',
#  '07892445:5',
#  '07892493:15',
#  '07892495:19',
#  '07892500:156',
#  '07892502:16',
#  '07892512:10',
#  '07892588:9',
#  '07892594:1',
#  '07892596:5',
#  '07892598:40',
#  '07892614:3',
#  '07892621:15',
#  '07892624:10',
#  '07892628:16',
#  '07892632:8',
#  '07892640:17',
#  '07892646:2',
#  '07892665:8',
#  '07892667:8',
#  '07892673:27',
#  '07892680:29',
#  '07892682:5',
#  '07892683:3',
#  '07892686:3',
#  '07892687:14',
#  '07892689:2',
#  '07892692:12',
#  '07892696:25',
#  '07892705:5',
#  '07892706:4',
#  '07892710:5',
#  '07892713:5',
#  '07892723:2',
#  '07892856:4',
#  '07892858:8',
#  '07892866:7',
#  '07892867:3',
#  '07892868:1',
#  '07892869:5',
#  '07892888:7',
#  '07892894:11',
#  '07892895:12',
#  '07892896:12',
#  '07892898:11',
#  '07892899:8',
#  '07892911:7',
#  '07892913:10',
#  '07892918:4',
#  '07892925:7',
#  '07892926:13',
#  '07892929:6',
#  '07892933:13',
#  '07892937:22',
#  '07892949:21',
#  '07892955:21',
#  '07892966:12',
#  '07892967:3',
#  '07892969:6',
#  '07892970:2',
#  '07892971:2',
#  '07892976:6',
#  '07892977:4',
#  '07892982:30',
#  '07892984:3',
#  '07892986:4',
#  '07892988:7',
#  '07892990:10',
#  '07892994:1',
#  '07892995:6',
#  '07893013:6',
#  '07893127:11',
#  '07893131:6',
#  '07893139:10',
#  '07893141:34',
#  '07893167:5',
#  '07893171:4',
#  '07893183:13',
#  '07893189:25',
#  '07893190:8',
#  '07893229:2',
#  '07893276:5',
#  '07893328:13',
#  '07893330:10',
#  '07893332:1',
#  '07893335:1',
#  '07893337:34',
#  '07893342:21',
#  '07893345:10',
#  '07893349:3',
#  '07893355:5',
#  '07893364:9',
#  '07893369:4',
#  '07893373:31',
#  '07893375:5',
#  '07893376:4',
#  '07893382:14',
#  '07893392:13',
#  '07893395:8',
#  '07893402:14',
#  '07893403:13',
#  '07893411:5',
#  '07893412:14',
#  '07893417:34',
#  '07893421:3',
#  '07893422:4',
#  '07893430:10',
#  '07893432:3',
#  '07893436:1',
#  '07893441:1',
#  '07893446:10',
#  '07893448:17',
#  '07893450:5',
#  '07893451:57',
#  '07893453:5',
#  '07893457:8',
#  '07893459:25',
#  '07893465:7',
#  '07893468:2',
#  '07893469:12',
#  '07893474:3',
#  '07893483:6',
#  '07893486:5',
#  '07893488:2',
#  '07893489:3',
#  '07893490:3',
#  '07893499:3',
#  '07893502:2',
#  '07893508:4',
#  '07893511:4',
#  '07893517:5',
#  '07893519:7',
#  '07893520:21',
#  '07893522:6',
#  '07893526:8',
#  '07893527:2',
#  '07893528:7',
#  '07893530:20',
#  '07893531:8',
#  '07893539:4',
#  '07893543:7',
#  '07893547:5',
#  '07893550:7',
#  '07893551:14',
#  '07893556:34',
#  '07893559:6',
#  '07893560:33',
#  '07893561:21',
#  '07893565:8',
#  '07893566:10',
#  '07893568:7',
#  '07893569:7',
#  '07893570:26',
#  '07893572:35',
#  '07893573:15',
#  '07893580:4',
#  '07893581:10',
#  '07893582:15',
#  '07893583:8',
#  '07893584:3',
#  '07893586:14',
#  '07893589:22',
#  '07893598:13',
#  '07893603:13',
#  '07893606:4',
#  '07893615:6',
#  '07893618:3',
#  '07893619:20',
#  '07893622:7',
#  '07893626:4',
#  '07893627:9',
#  '07893628:5',
#  '07893629:8',
#  '07893633:9',
#  '07893636:21',
#  '07893641:31',
#  '07893645:22',
#  '07893647:17',
#  '07893648:23',
#  '07893649:8',
#  '07893654:6',
#  '07893663:3',
#  '07893664:4',
#  '07893666:12',
#  '07893670:4',
#  '07893673:7',
#  '07893677:3',
#  '07893679:1',
#  '07893680:9',
#  '07893684:2',
#  '07893687:4',
#  '07893688:9',
#  '07893696:5',
#  '07893699:14',
#  '07893702:10',
#  '07893706:7',
#  '07893707:3',
#  '07893709:15',
#  '07893715:3',
#  '07893718:5',
#  '07893720:3',
#  '07893726:4',
#  '07893730:11',
#  '07893733:5',
#  '07893734:7',
#  '07893738:24',
#  '07893746:7',
#  '07893747:7',
#  '07893749:5',
#  '07893751:23',
#  '07893755:10',
#  '07893760:18',
#  '07893761:1',
#  '07893764:9',
#  '07893765:5',
#  '07893768:7',
#  '07893770:12',
#  '07893779:2',
#  '07893782:7',
#  '07893783:4',
#  '07893787:21',
#  '07893788:3',
#  '07893798:12',
#  '07893800:9',
#  '07893804:4',
#  '07893805:4',
#  '07893810:7',
#  '07893815:28',
#  '07893818:7',
#  '07893819:24',
#  '07893821:3',
#  '07893822:7',
#  '07893823:12',
#  '07893825:25',
#  '07893833:9',
#  '07893834:15',
#  '07893841:7',
#  '07893843:13',
#  '07893844:3',
#  '07893849:21',
#  '07893857:10',
#  '07893858:2',
#  '07893861:7',
#  '07893863:6',
#  '07893864:8',
#  '07893877:6',
#  '07893883:29',
#  '07893886:11',
#  '07893887:10',
#  '07893888:12',
#  '07893893:1',
#  '07893894:8',
#  '07893899:21',
#  '07893903:15',
#  '07893904:7',
#  '07893906:6',
#  '07893912:1',
#  '07893917:15',
#  '07893920:17',
#  '07893921:8',
#  '07893923:15',
#  '07893926:13',
#  '07893928:7',
#  '07893933:34',
#  '07893942:5',
#  '07893945:6',
#  '07893946:12',
#  '07893949:6',
#  '07893951:11',
#  '07893953:10',
#  '07893955:18',
#  '07893960:2',
#  '07893961:9',
#  '07893964:11',
#  '07893966:5',
#  '07893969:11',
#  '07893972:20',
#  '07893974:8',
#  '07893980:6',
#  '07893982:18',
#  '07893998:13',
#  '07894001:13',
#  '07894008:29',
#  '07894009:3',
#  '07894011:22',
#  '07894027:3',
#  '07894030:19',
#  '07894035:2',
#  '07894036:10',
#  '07894046:2',
#  '07894048:5',
#  '07894051:6',
#  '07894053:3',
#  '07894062:5',
#  '07894063:4',
#  '07894064:12',
#  '07894069:1',
#  '07894079:8',
#  '07894080:6',
#  '07894088:10',
#  '07894094:18',
#  '07894101:9',
#  '07894105:35',
#  '07894107:7',
#  '07894111:10',
#  '07894113:4',
#  '07894114:15',
#  '07894116:6',
#  '07894127:2',
#  '07894133:7',
#  '07894134:8',
#  '07894138:8',
#  '07894142:12',
#  '07894143:3',
#  '07894144:6',
#  '07894147:16',
#  '07894151:30',
#  '07894153:7',
#  '07894154:5',
#  '07894156:10',
#  '07894161:20',
#  '07894166:5',
#  '07894168:6',
#  '07894170:9',
#  '07894171:10',
#  '07894172:29',
#  '07894174:77',
#  '07894176:2',
#  '07894179:29',
#  '07894180:3',
#  '07894181:11',
#  '07894184:9',
#  '07894188:3',
#  '07894189:10',
#  '07894191:14',
#  '07894195:21',
#  '07894196:18',
#  '07894199:9',
#  '07894200:11',
#  '07894201:11',
#  '07894202:9',
#  '07894204:5',
#  '07894206:9',
#  '07894212:14',
#  '07894213:8',
#  '07894214:3',
#  '07894215:18',
#  '07894221:2',
#  '07894226:6',
#  '07894231:7',
#  '07894233:1',
#  '07894238:5',
#  '07894240:3',
#  '07894241:12',
#  '07894242:4',
#  '07894243:3',
#  '07894247:6',
#  '07894250:9',
#  '07894252:7',
#  '07894260:15',
#  '07894261:1',
#  '07894264:8',
#  '07894266:17',
#  '07894268:6',
#  '07894271:5',
#  '07894272:3',
#  '07894275:12',
#  '07894276:8',
#  '07894279:3',
#  '07894280:13',
#  '07894281:9',
#  '07894282:10',
#  '07894283:4',
#  '07894285:10',
#  '07894286:65',
#  '07894287:7',
#  '07894288:7',
#  '07894290:5',
#  '07894291:18',
#  '07894292:8',
#  '07894293:9',
#  '07894295:9',
#  '07894296:11',
#  '07894307:28',
#  '07894313:2',
#  '07894314:4',
#  '07894320:13',
#  '07894323:4',
#  '07894327:17',
#  '07894344:12',
#  '07894346:13',
#  '07894349:3',
#  '07894351:13',
#  '07894357:20',
#  '07894359:23',
#  '07894361:8',
#  '07894363:4',
#  '07894365:23',
#  '07894367:5',
#  '07894369:6',
#  '07894370:9',
#  '07894376:10',
#  '07894379:3',
#  '07894381:15',
#  '07894385:8',
#  '07894387:7',
#  '07894390:3',
#  '07894391:8',
#  '07894393:11',
#  '07894394:11',
#  '07894414:4',
#  '07894415:10',
#  '07894419:13',
#  '07894422:27',
#  '07894426:16',
#  '07894430:6',
#  '07894434:7',
#  '07894437:4',
#  '07894438:8',
#  '07894454:8',
#  '07894463:5',
#  '07894465:8',
#  '07894469:12',
#  '07894472:19',
#  '07894477:12',
#  '07894488:14',
#  '07894497:5',
#  '07894502:28',
#  '07894505:18',
#  '07894506:9',
#  '07894507:15',
#  '07894537:3',
#  '07894539:10',
#  '07894545:115',
#  '07894547:2',
#  '07894552:6',
#  '07894553:1',
#  '07894554:6',
#  '07894556:8',
#  '07894563:11',
#  '07894566:7',
#  '07894571:4',
#  '07894573:11',
#  '07894575:5',
#  '07894578:3',
#  '07894579:6',
#  '07894585:6',
#  '07894589:8',
#  '07894598:5',
#  '07894601:11',
#  '07894607:5',
#  '07894613:5',
#  '07894626:8',
#  '07894629:94',
#  '07894630:13',
#  '07894638:6',
#  '07894653:11',
#  '07894655:6',
#  '07894656:174',
#  '07894657:3',
#  '07894658:24',
#  '07894669:2',
#  '07894670:1',
#  '07894689:47',
#  '07894690:3',
#  '07894692:4',
#  '07894700:3',
#  '07894708:3',
#  '07894715:9',
#  '07894720:6',
#  '07894722:3',
#  '07894723:19',
#  '07894726:14',
#  '07894729:3',
#  '07894732:21',
#  '07894733:45',
#  '07894735:8',
#  '07894738:14',
#  '07894739:4',
#  '07894745:4',
#  '07894746:8',
#  '07894760:11',
#  '07894765:9',
#  '07894767:4',
#  '07894768:2',
#  '07894771:22',
#  '07894772:9',
#  '07894779:22',
#  '07894781:4',
#  '07894785:6',
#  '07894786:12',
#  '07894787:2',
#  '07894792:4',
#  '07894793:7',
#  '07894794:18',
#  '07894798:9',
#  '07894800:10',
#  '07894811:3',
#  '07894818:177',
#  '07894824:24',
#  '07894829:30',
#  '07894841:3',
#  '07894844:6',
#  '07894846:17',
#  '07894852:2',
#  '07894853:8',
#  '07894854:17',
#  '07894856:11',
#  ...]

# %% [markdown]
# ## 5. Preprocessing the abstracts
#
# The goal of text pre-processing is to convert unstructure text into structured data. For this analysis, a sparse count vector is produced.
#
# Pre-processing of the abstract text is achieved using the following steps:
#   -   initial tokenisation, conversion to lower case, and removal of non-alpha tokens.
#   -   lemmatisation for nouns, e.g. surfaces -> surface
#   -   removal of stopwords
#   -   identification and removal of the 20 most frequent words according to document frequency
#   -   identification and removal of the those words that appear in only one document
#   -   identification of meaningful bigrams, and replacement of unigram tokens with bigrams for 100 of the most meaningful.
#   -   creation of a vocabulary for the patent abstracts, containing words (tokens) with lexical significance.
#   -   reduction of final tokenised abstracts to a sparse count vector

# %% [markdown]
# ### 5.1 Pre-processing Functions
# The functions used to tokenise, remove tokens (stopwords and most and least used words) and create the document statistics are shown below.

# %%
# Code to tokenize the abstract

# %% [markdown]
# ### 5.2  Tokenise Abstracts
# The abstracts are tokenized to return only those tokens that are alphabetical (tokens containing numbers or symbols are not considered meaningful for this analysis).  The tokenisation also converts the case of all tokens to lowercase.

# %%
# Out:
# Number of tokens: 	216791
# Vocabulary: 		9690
# Lexical Diversity: 	0.0446974274762

# %% [markdown]
# ### 5.3 Stemming / Lemmatisation
# For the purposes of this analysis, it is useful to stem/lemmatise the tokens. The nltk lemmatiser is used to remove pluralisation of nouns, resulting in a decrease in the vocabulary - but not affecting the overall count of tokens. The lemmatisation has been performed prior to the identification of word document frequencies and bigrams to ensure that plural forms of nouns are grouped with their non-plural forms when assessing 'meaningful bigrams' and word frequency.
#
# It is noted that more sophisticated lemmatisation can be achieved by using POS tagging, however for the purposes of this analysis, the scope of lemmatisation is limited to treating all tokens as nouns (the default).

# %%
# Out:
# Number of tokens: 	216791
# Vocabulary: 		8506
# Lexical Diversity: 	0.0392359461417

# %% [markdown]
# The effect of lemmatisation is to reduce the vocabulary by 1184 words.
# The words affected are shown below, and as expected are mainly associated with reducing the plural form of a word to its singular form:

# %%
# Out:
# ['abbreviations -> abbreviation',
#  'abilities -> ability',
#  'acaricides -> acaricide',
#  'accelerations -> acceleration',
#  'accesses -> access',
#  'accessories -> accessory',
#  'accidents -> accident',
#  'accounts -> account',
#  'acids -> acid',
#  'actions -> action',
#  'activations -> activation',
#  'activities -> activity',
#  'acts -> act',
#  'actuators -> actuator',
#  'adapters -> adapter',
#  'additives -> additive',
#  'addresses -> address',
#  'adds -> add',
#  'adhesives -> adhesive',
#  'adjusters -> adjuster',
#  'advances -> advance',
#  'advantages -> advantage',
#  'advertisements -> advertisement',
#  'affects -> affect',
#  'agents -> agent',
#  'agglomerations -> agglomeration',
#  'aides -> aide',
#  'aids -> aid',
#  'aims -> aim',
#  'airplanes -> airplane',
#  'airways -> airway',
#  'alarms -> alarm',
#  'alerts -> alert',
#  'algorithms -> algorithm',
#  'alloys -> alloy',
#  'amounts -> amount',
#  'amplifiers -> amplifier',
#  'amps -> amp',
#  'analyses -> analysis',
#  'anchors -> anchor',
#  'angles -> angle',
#  'animals -> animal',
#  'anodes -> anode',
#  'anomalies -> anomaly',
#  'answers -> answer',
#  'antennas -> antenna',
#  'apertures -> aperture',
#  'apexes -> apex',
#  'apparatuses -> apparatus',
#  'applications -> application',
#  'appliques -> applique',
#  'approximations -> approximation',
#  'archives -> archive',
#  'arcs -> arc',
#  'areas -> area',
#  'armatures -> armature',
#  'arms -> arm',
#  'arrangements -> arrangement',
#  'arrays -> array',
#  'arteries -> artery',
#  'articles -> article',
#  'artifacts -> artifact',
#  'arts -> art',
#  'aspects -> aspect',
#  'asphalts -> asphalt',
#  'assays -> assay',
#  'assemblies -> assembly',
#  'assess -> ass',
#  'assists -> assist',
#  'associates -> associate',
#  'atoms -> atom',
#  'attaches -> attache',
#  'attempts -> attempt',
#  'attractions -> attraction',
#  'attributes -> attribute',
#  'auctions -> auction',
#  'authorities -> authority',
#  'automobiles -> automobile',
#  'awards -> award',
#  'axes -> ax',
#  'axles -> axle',
#  'backups -> backup',
#  'baffles -> baffle',
#  'bags -> bag',
#  'balances -> balance',
#  'bales -> bale',
#  'balls -> ball',
#  'bands -> band',
#  'banks -> bank',
#  'barbs -> barb',
#  'barrels -> barrel',
#  'barriers -> barrier',
#  'bars -> bar',
#  'bases -> base',
#  'baskets -> basket',
#  'batches -> batch',
#  'batteries -> battery',
#  'beaches -> beach',
#  'beads -> bead',
#  'beams -> beam',
#  'beans -> bean',
#  'bearings -> bearing',
#  'beats -> beat',
#  'beetles -> beetle',
#  'begins -> begin',
#  'behaviors -> behavior',
#  'beings -> being',
#  'bellows -> bellow',
#  'belts -> belt',
#  'bends -> bend',
#  'benefits -> benefit',
#  'bets -> bet',
#  'biases -> bias',
#  'bills -> bill',
#  'binaries -> binary',
#  'bins -> bin',
#  'bits -> bit',
#  'bladders -> bladder',
#  'blades -> blade',
#  'blanks -> blank',
#  'blemishes -> blemish',
#  'blends -> blend',
#  'blocks -> block',
#  'blowers -> blower',
#  'blows -> blow',
#  'boards -> board',
#  'boats -> boat',
#  'bobbins -> bobbin',
#  'bodies -> body',
#  'bolts -> bolt',
#  'bonds -> bond',
#  'books -> book',
#  'boss -> bos',
#  'bosses -> boss',
#  'bottles -> bottle',
#  'bottoms -> bottom',
#  'boundaries -> boundary',
#  'bowels -> bowel',
#  'brackets -> bracket',
#  'brakes -> brake',
#  'branches -> branch',
#  'brands -> brand',
#  'breaks -> break',
#  'breasts -> breast',
#  'bridges -> bridge',
#  'brightnesses -> brightness',
#  'bristles -> bristle',
#  'brushes -> brush',
#  'btus -> btu',
#  'bubbles -> bubble',
#  'buckets -> bucket',
#  'buckles -> buckle',
#  'buffers -> buffer',
#  'builds -> build',
#  'bulges -> bulge',
#  'bumps -> bump',
#  'bundles -> bundle',
#  'bursts -> burst',
#  'busbars -> busbar',
#  'buses -> bus',
#  'bushes -> bush',
#  'bushings -> bushing',
#  'butterflies -> butterfly',
#  'buttocks -> buttock',
#  'buttons -> button',
#  'byproducts -> byproduct',
#  'bytes -> byte',
#  'cables -> cable',
#  'calculations -> calculation',
#  'calculators -> calculator',
#  'calls -> call',
#  'canals -> canal',
#  'candidates -> candidate',
#  'canes -> cane',
#  'cantilevers -> cantilever',
#  'capabilities -> capability',
#  'capacitances -> capacitance',
#  'capacities -> capacity',
#  'capacitors -> capacitor',
#  'caps -> cap',
#  'captures -> capture',
#  'cards -> card',
#  'carriers -> carrier',
#  'carries -> carry',
#  'cartridges -> cartridge',
#  'carts -> cart',
#  'cases -> case',
#  'casings -> casing',
#  'cassettes -> cassette',
#  'casters -> caster',
#  'categories -> category',
#  'causes -> cause',
#  'cavities -> cavity',
#  'ceilings -> ceiling',
#  'cellars -> cellar',
#  'cells -> cell',
#  'chains -> chain',
#  'chairs -> chair',
#  'chambers -> chamber',
#  'changes -> change',
#  'channels -> channel',
#  'characteristics -> characteristic',
#  'characters -> character',
#  'charges -> charge',
#  'chemicals -> chemical',
#  'children -> child',
#  'chinks -> chink',
#  'chips -> chip',
#  'chucks -> chuck',
#  'chunks -> chunk',
#  'chutes -> chute',
#  'cids -> cid',
#  'circuitries -> circuitry',
#  'circuits -> circuit',
#  'circumferences -> circumference',
#  'circumstances -> circumstance',
#  'cis -> ci',
#  'claims -> claim',
#  'clamps -> clamp',
#  'classes -> class',
#  'clearances -> clearance',
#  'clients -> client',
#  'climbs -> climb',
#  'clippings -> clipping',
#  'clips -> clip',
#  'clocks -> clock',
#  'clogs -> clog',
#  'closes -> close',
#  'clubs -> club',
#  'clusters -> cluster',
#  'clutches -> clutch',
#  'coatings -> coating',
#  'codes -> code',
#  'coefficients -> coefficient',
#  'coils -> coil',
#  'collapses -> collapse',
#  'collectors -> collector',
#  'collects -> collect',
#  'collisions -> collision',
#  'colors -> color',
#  'columns -> column',
#  'combinations -> combination',
#  'combines -> combine',
#  'comes -> come',
#  'commands -> command',
#  'communications -> communication',
#  'companies -> company',
#  'compares -> compare',
#  'comparisons -> comparison',
#  'compartments -> compartment',
#  'complexes -> complex',
#  'components -> component',
#  'compositions -> composition',
#  'compounds -> compound',
#  'compresses -> compress',
#  'compressions -> compression',
#  'computations -> computation',
#  'computers -> computer',
#  'concentrates -> concentrate',
#  'concentrations -> concentration',
#  'concerns -> concern',
#  'conditioners -> conditioner',
#  'conditions -> condition',
#  'conductors -> conductor',
#  'conduits -> conduit',
#  'configurations -> configuration',
#  'conflicts -> conflict',
#  'connections -> connection',
#  'connectors -> connector',
#  'considerations -> consideration',
#  'consoles -> console',
#  'constants -> constant',
#  'constraints -> constraint',
#  'constructs -> construct',
#  'contacts -> contact',
#  'containers -> container',
#  'contaminants -> contaminant',
#  'contents -> content',
#  'contexts -> context',
#  'contours -> contour',
#  'contractions -> contraction',
#  'controllers -> controller',
#  'controls -> control',
#  'conversions -> conversion',
#  'converters -> converter',
#  'converts -> convert',
#  'conveyers -> conveyer',
#  'conveyors -> conveyor',
#  'cools -> cool',
#  'coordinates -> coordinate',
#  'copies -> copy',
#  'cords -> cord',
#  'cores -> core',
#  'corners -> corner',
#  'corrections -> correction',
#  'costs -> cost',
#  'counters -> counter',
#  'counts -> count',
#  'couples -> couple',
#  'couplings -> coupling',
#  'courses -> course',
#  'coveralls -> coverall',
#  'covers -> cover',
#  'crackers -> cracker',
#  'credentials -> credential',
#  'crews -> crew',
#  'criteria -> criterion',
#  'crops -> crop',
#  'crossbars -> crossbar',
#  'crossovers -> crossover',
#  'crushes -> crush',
#  'crustaceans -> crustacean',
#  'cubes -> cube',
#  'cues -> cue',
#  'cuffs -> cuff',
#  'cups -> cup',
#  'cures -> cure',
#  'currents -> current',
#  'curves -> curve',
#  'customers -> customer',
#  'cutouts -> cutout',
#  'cuts -> cut',
#  'cycles -> cycle',
#  'cylinders -> cylinder',
#  'damages -> damage',
#  'dampers -> damper',
#  'databases -> database',
#  'dealers -> dealer',
#  'deals -> deal',
#  'deaths -> death',
#  'decisions -> decision',
#  'decompositions -> decomposition',
#  'decreases -> decrease',
#  'defects -> defect',
#  'deficiencies -> deficiency',
#  'deformations -> deformation',
#  'degrees -> degree',
#  'delays -> delay',
#  'deliverables -> deliverable',
#  'densities -> density',
#  'dependencies -> dependency',
#  'depositions -> deposition',
#  'deposits -> deposit',
#  'depressions -> depression',
#  'derivatives -> derivative',
#  'descriptions -> description',
#  'designs -> design',
#  'destinations -> destination',
#  'detectors -> detector',
#  'detents -> detent',
#  'developers -> developer',
#  'deviates -> deviate',
#  'devices -> device',
#  'diagnoses -> diagnosis',
#  'diameters -> diameter',
#  'diaphragms -> diaphragm',
#  'dictionaries -> dictionary',
#  'dies -> dy',
#  'differences -> difference',
#  'differentials -> differential',
#  'dimensions -> dimension',
#  'diodes -> diode',
#  'directions -> direction',
#  'directories -> directory',
#  'disadvantages -> disadvantage',
#  'discards -> discard',
#  'discharges -> discharge',
#  'disconnects -> disconnect',
#  'discrepancies -> discrepancy',
#  'discs -> disc',
#  'disinfectants -> disinfectant',
#  'disks -> disk',
#  'disorders -> disorder',
#  'dispensations -> dispensation',
#  'displacements -> displacement',
#  'displays -> display',
#  'distances -> distance',
#  'distillates -> distillate',
#  'distributions -> distribution',
#  'distributors -> distributor',
#  'disturbances -> disturbance',
#  'divides -> divide',
#  'divisions -> division',
#  'documents -> document',
#  'does -> doe',
#  'dolls -> doll',
#  'domains -> domain',
#  'domes -> dome',
#  'doors -> door',
#  'dots -> dot',
#  'doubles -> double',
#  'drafts -> draft',
#  'drains -> drain',
#  'draws -> draw',
#  'drivers -> driver',
#  'drives -> drive',
#  'droplets -> droplet',
#  'drops -> drop',
#  'drugs -> drug',
#  'drumheads -> drumhead',
#  'drums -> drum',
#  'ducts -> duct',
#  'durations -> duration',
#  'dyes -> dye',
#  'dynamics -> dynamic',
#  'ears -> ear',
#  'edges -> edge',
#  'effects -> effect',
#  'effluents -> effluent',
#  'efforts -> effort',
#  'elbows -> elbow',
#  'electrodes -> electrode',
#  'electromagnets -> electromagnet',
#  'electrons -> electron',
#  'elements -> element',
#  'elevations -> elevation',
#  'elevators -> elevator',
#  'ellipses -> ellipsis',
#  'embodiments -> embodiment',
#  'emitters -> emitter',
#  'emotions -> emotion',
#  'employs -> employ',
#  'emulsifiers -> emulsifier',
#  'enclosures -> enclosure',
#  'encounters -> encounter',
#  'ends -> end',
#  'engines -> engine',
#  'enhancements -> enhancement',
#  'ensembles -> ensemble',
#  'entails -> entail',
#  'entities -> entity',
#  'entrances -> entrance',
#  'entries -> entry',
#  'envelopes -> envelope',
#  'environments -> environment',
#  'equalizers -> equalizer',
#  'equals -> equal',
#  'equivalents -> equivalent',
#  'errors -> error',
#  'esters -> ester',
#  'estimates -> estimate',
#  'estimators -> estimator',
#  'events -> event',
#  'examples -> example',
#  'exchanges -> exchange',
#  'exercises -> exercise',
#  'exits -> exit',
#  'expenses -> expense',
#  'experiences -> experience',
#  'experiments -> experiment',
#  'experts -> expert',
#  'explorations -> exploration',
#  'exposes -> expose',
#  'expresses -> express',
#  'expressions -> expression',
#  'extensions -> extension',
#  'extracts -> extract',
#  'eyeglasses -> eyeglass',
#  'eyes -> eye',
#  'faceplates -> faceplate',
#  'faces -> face',
#  'facets -> facet',
#  'factors -> factor',
#  'failures -> failure',
#  'falls -> fall',
#  'fans -> fan',
#  'fashions -> fashion',
#  'fasteners -> fastener',
#  'faucets -> faucet',
#  'faults -> fault',
#  'features -> feature',
#  'feet -> foot',
#  'fenders -> fender',
#  'fetches -> fetch',
#  'fibers -> fiber',
#  'fields -> field',
#  'filaments -> filament',
#  'files -> file',
#  'fillers -> filler',
#  'fills -> fill',
#  'films -> film',
#  'filters -> filter',
#  'finds -> find',
#  'fines -> fine',
#  'fingers -> finger',
#  'finishers -> finisher',
#  'fins -> fin',
#  'firefighters -> firefighter',
#  'fits -> fit',
#  'fittings -> fitting',
#  'fixes -> fix',
#  'fixtures -> fixture',
#  'flakes -> flake',
#  'flanges -> flange',
#  'flanks -> flank',
#  'flaps -> flap',
#  'flares -> flare',
#  'flats -> flat',
#  'floors -> floor',
#  'flows -> flow',
#  'fluctuations -> fluctuation',
#  'fluids -> fluid',
#  'fms -> fm',
#  'focuses -> focus',
#  'fogs -> fog',
#  'folds -> fold',
#  'foodstuffs -> foodstuff',
#  'footrests -> footrest',
#  'forces -> force',
#  'forks -> fork',
#  'formations -> formation',
#  'formats -> format',
#  'forms -> form',
#  'formulae -> formula',
#  'formulations -> formulation',
#  'forwards -> forward',
#  'fragments -> fragment',
#  'frames -> frame',
#  'frees -> free',
#  'frequencies -> frequency',
#  'fulcrums -> fulcrum',
#  'functions -> function',
#  'funds -> fund',
#  'furnaces -> furnace',
#  'furnishings -> furnishing',
#  'fuses -> fuse',
#  'gains -> gain',
#  'games -> game',
#  'gaps -> gap',
#  'garments -> garment',
#  'gases -> gas',
#  'gates -> gate',
#  'gauges -> gauge',
#  'gears -> gear',
#  'generators -> generator',
#  'genes -> gene',
#  'gets -> get',
#  'gifts -> gift',
#  'gives -> give',
#  'glues -> glue',
#  'goes -> go',
#  'goods -> good',
#  'gradients -> gradient',
#  'grains -> grain',
#  'grasps -> grasp',
#  'gratings -> grating',
#  'grilles -> grille',
#  'grinds -> grind',
#  'grips -> grip',
#  'grooves -> groove',
#  'groups -> group',
#  'guarantees -> guarantee',
#  'guides -> guide',
#  'gyroscopes -> gyroscope',
#  'habits -> habit',
#  'halves -> half',
#  'handlebars -> handlebar',
#  'handles -> handle',
#  'hands -> hand',
#  'harmonics -> harmonic',
#  'has -> ha',
#  'hazards -> hazard',
#  'headlamps -> headlamp',
#  'heads -> head',
#  'heaters -> heater',
#  'heats -> heat',
#  'heights -> height',
#  'helps -> help',
#  'hemorrhoids -> hemorrhoid',
#  'herbs -> herb',
#  'hernias -> hernia',
#  'highlighters -> highlighter',
#  'hinges -> hinge',
#  'hints -> hint',
#  'histograms -> histogram',
#  'holders -> holder',
#  'holds -> hold',
#  'holes -> hole',
#  'hollows -> hollow',
#  'hooks -> hook',
#  'hoops -> hoop',
#  'hormones -> hormone',
#  'horns -> horn',
#  'horses -> horse',
#  'hoses -> hose',
#  'houses -> house',
#  'housings -> housing',
#  'humans -> human',
#  'hydrates -> hydrate',
#  'hydrocarbons -> hydrocarbon',
#  'hypotheses -> hypothesis',
#  'identifiers -> identifier',
#  'images -> image',
#  'imbalances -> imbalance',
#  'immigrants -> immigrant',
#  'impacts -> impact',
#  'implants -> implant',
#  'implementations -> implementation',
#  'implements -> implement',
#  'improvements -> improvement',
#  'impurities -> impurity',
#  'inches -> inch',
#  'incidences -> incidence',
#  'incidents -> incident',
#  'inclusions -> inclusion',
#  'increases -> increase',
#  'increments -> increment',
#  'indentations -> indentation',
#  'indexes -> index',
#  'indications -> indication',
#  'indicators -> indicator',
#  'indices -> index',
#  'individuals -> individual',
#  'inductors -> inductor',
#  'inflows -> inflow',
#  'ingredients -> ingredient',
#  'ingress -> ingres',
#  'initiates -> initiate',
#  'injuries -> injury',
#  'inks -> ink',
#  'inlets -> inlet',
#  'inputs -> input',
#  'insecticides -> insecticide',
#  'inserts -> insert',
#  'insides -> inside',
#  'insignias -> insignia',
#  'installations -> installation',
#  'instances -> instance',
#  'instructions -> instruction',
#  'instruments -> instrument',
#  'insureds -> insured',
#  'integers -> integer',
#  'integrators -> integrator',
#  'intensities -> intensity',
#  'interactions -> interaction',
#  'interconnections -> interconnection',
#  'interfaces -> interface',
#  'intermediates -> intermediate',
#  'interrupts -> interrupt',
#  'intervals -> interval',
#  'intruders -> intruder',
#  'inventions -> invention',
#  'inverters -> inverter',
#  'ions -> ion',
#  'irregularities -> irregularity',
#  'islands -> island',
#  'issues -> issue',
#  'items -> item',
#  'its -> it',
#  'jackets -> jacket',
#  'jars -> jar',
#  'jaws -> jaw',
#  'jets -> jet',
#  'jitters -> jitter',
#  'joins -> join',
#  'joints -> joint',
#  'jokers -> joker',
#  'joysticks -> joystick',
#  'judges -> judge',
#  'jumps -> jump',
#  'junctions -> junction',
#  'juniors -> junior',
#  'kayaks -> kayak',
#  'keeps -> keep',
#  'ketones -> ketone',
#  'keys -> key',
#  'kits -> kit',
#  'kneels -> kneel',
#  'knees -> knee',
#  'knives -> knife',
#  'knuckles -> knuckle',
#  'labels -> label',
#  'laminations -> lamination',
#  'lamps -> lamp',
#  'lances -> lance',
#  'lands -> land',
#  'lanes -> lane',
#  'latches -> latch',
#  'layers -> layer',
#  'lays -> lay',
#  'leads -> lead',
#  'leaks -> leak',
#  'learners -> learner',
#  'leaves -> leaf',
#  'leds -> led',
#  'legs -> leg',
#  'lengths -> length',
#  'lenses -> lens',
#  'less -> le',
#  'lets -> let',
#  'levels -> level',
#  'levers -> lever',
#  'lies -> lie',
#  'lifters -> lifter',
#  'lights -> light',
#  'likelihoods -> likelihood',
#  'limbs -> limb',
#  'limitations -> limitation',
#  'limits -> limit',
#  'lines -> line',
#  'linings -> lining',
#  'links -> link',
#  'liquids -> liquid',
#  'listings -> listing',
#  'lms -> lm',
#  'loadings -> loading',
#  'loads -> load',
#  'lobes -> lobe',
#  'locations -> location',
#  'locks -> lock',
#  'logos -> logo',
#  'logs -> log',
#  'looks -> look',
#  'loops -> loop',
#  'losses -> loss',
#  'lowers -> lower',
#  'lugs -> lug',
#  'lungs -> lung',
#  'machines -> machine',
#  'macros -> macro',
#  'magazines -> magazine',
#  'magnetizations -> magnetization',
#  'magnets -> magnet',
#  'magnitudes -> magnitude',
#  'mailboxes -> mailbox',
#  'makes -> make',
#  'mandrels -> mandrel',
#  'manifolds -> manifold',
#  'manufacturers -> manufacturer',
#  'maps -> map',
#  'markers -> marker',
#  'markings -> marking',
#  'marks -> mark',
#  'masks -> mask',
#  'matches -> match',
#  'materials -> material',
#  'mates -> mate',
#  'matrices -> matrix',
#  'maxima -> maximum',
#  'mcs -> mc',
#  'means -> mean',
#  'measurements -> measurement',
#  'measures -> measure',
#  'mechanisms -> mechanism',
#  'medals -> medal',
#  'media -> medium',
#  'mediums -> medium',
#  'meets -> meet',
#  'melts -> melt',
#  'members -> member',
#  'membranes -> membrane',
#  'mems -> mem',
#  'merchants -> merchant',
#  'meshes -> mesh',
#  'messages -> message',
#  'metabolites -> metabolite',
#  'metals -> metal',
#  'meters -> meter',
#  'methods -> method',
#  'metrics -> metric',
#  'mice -> mouse',
#  'microcircuits -> microcircuit',
#  'microprocessors -> microprocessor',
#  'miniatures -> miniature',
#  'mirrors -> mirror',
#  'miters -> miter',
#  'mixers -> mixer',
#  'mixes -> mix',
#  'mixtures -> mixture',
#  'mms -> mm',
#  'models -> model',
#  'modes -> mode',
#  'modulations -> modulation',
#  'modules -> module',
#  'moieties -> moiety',
#  'molecules -> molecule',
#  'monitors -> monitor',
#  'monomers -> monomer',
#  'mos -> mo',
#  'motions -> motion',
#  'motors -> motor',
#  'mountings -> mounting',
#  'mounts -> mount',
#  'mouths -> mouth',
#  'movements -> movement',
#  'moves -> move',
#  'multiples -> multiple',
#  'multiplexers -> multiplexer',
#  'muscles -> muscle',
#  'nails -> nail',
#  'names -> name',
#  'narrows -> narrow',
#  'nas -> na',
#  'necks -> neck',
#  'needles -> needle',
#  'needs -> need',
#  'nerves -> nerve',
#  'nets -> net',
#  'networks -> network',
#  'neurons -> neuron',
#  'nitrides -> nitride',
#  'nodes -> node',
#  'notches -> notch',
#  'notifications -> notification',
#  'nozzles -> nozzle',
#  'nubs -> nub',
#  'numbers -> number',
#  'nutrients -> nutrient',
#  'nuts -> nut',
#  'nvs -> nv',
#  'objects -> object',
#  'obstacles -> obstacle',
#  'occurrences -> occurrence',
#  'offerings -> offering',
#  'offers -> offer',
#  'offsets -> offset',
#  'ones -> one',
#  'openings -> opening',
#  'opens -> open',
#  'operations -> operation',
#  'operators -> operator',
#  'optics -> optic',
#  'options -> option',
#  'orders -> order',
#  'organisms -> organism',
#  'organizations -> organization',
#  'orientations -> orientation',
#  'orifices -> orifice',
#  'oscillations -> oscillation',
#  'outcomes -> outcome',
#  'outflows -> outflow',
#  'outlets -> outlet',
#  'outputs -> output',
#  'overlaps -> overlap',
#  'overlays -> overlay',
#  'overloads -> overload',
#  'packages -> package',
#  'packers -> packer',
#  'packets -> packet',
#  'packs -> pack',
#  'paddles -> paddle',
#  'pads -> pad',
#  'pages -> page',
#  'pails -> pail',
#  'paints -> paint',
#  'pairs -> pair',
#  'panels -> panel',
#  'panes -> pane',
#  'pants -> pant',
#  'papers -> paper',
#  'parameters -> parameter',
#  'parasites -> parasite',
#  'parasols -> parasol',
#  'parses -> par',
#  'particles -> particle',
#  'parties -> party',
#  'partitions -> partition',
#  'partners -> partner',
#  'parts -> part',
#  'pass -> pas',
#  'passages -> passage',
#  'passageways -> passageway',
#  'passengers -> passenger',
#  'passes -> pass',
#  'passports -> passport',
#  'patches -> patch',
#  'paths -> path',
#  'pathways -> pathway',
#  'patients -> patient',
#  'patios -> patio',
#  'patrons -> patron',
#  'patterns -> pattern',
#  'pauses -> pause',
#  'pawls -> pawl',
#  'peaks -> peak',
#  'pedals -> pedal',
#  'peels -> peel',
#  'peers -> peer',
#  'pegs -> peg',
#  'percentages -> percentage',
#  'percolates -> percolate',
#  'perforations -> perforation',
#  'periods -> period',
#  'peripheries -> periphery',
#  'permissions -> permission',
#  'permits -> permit',
#  'personalities -> personality',
#  'persons -> person',
#  'perspectives -> perspective',
#  'pes -> pe',
#  'pesticides -> pesticide',
#  'pets -> pet',
#  'pharmaceuticals -> pharmaceutical',
#  'phases -> phase',
#  'phones -> phone',
#  'photons -> photon',
#  'picks -> pick',
#  'pieces -> piece',
#  'pigments -> pigment',
#  'pillars -> pillar',
#  'pins -> pin',
#  'pipes -> pipe',
#  'pivots -> pivot',
#  'pixels -> pixel',
#  'places -> place',
#  'planes -> plane',
#  'plans -> plan',
#  'plants -> plant',
#  'plastics -> plastic',
#  'plates -> plate',
#  'platforms -> platform',
#  'players -> player',
#  'plays -> play',
#  'pleats -> pleat',
#  'plenums -> plenum',
#  'pliers -> plier',
#  'plugs -> plug',
#  'plumes -> plume',
#  'pluralities -> plurality',
#  'plurals -> plural',
#  'pockets -> pocket',
#  'pointers -> pointer',
#  'points -> point',
#  'poles -> pole',
#  'policies -> policy',
#  'pollutants -> pollutant',
#  'polymers -> polymer',
#  'polypeptides -> polypeptide',
#  'pontoons -> pontoon',
#  'pools -> pool',
#  'pores -> pore',
#  'portals -> portal',
#  'portions -> portion',
#  'ports -> port',
#  'pos -> po',
#  'positions -> position',
#  'positives -> positive',
#  'possess -> posse',
#  'possesses -> posse',
#  'posts -> post',
#  'potentials -> potential',
#  'pots -> pot',
#  'pouches -> pouch',
#  'pounds -> pound',
#  'powers -> power',
#  'precursors -> precursor',
#  'predictions -> prediction',
#  'preferences -> preference',
#  'preparations -> preparation',
#  'prescriptions -> prescription',
#  'presents -> present',
#  'preservatives -> preservative',
#  'preserves -> preserve',
#  'presses -> press',
#  'pressures -> pressure',
#  'prices -> price',
#  'prints -> print',
#  'prisms -> prism',
#  'probabilities -> probability',
#  'probes -> probe',
#  'problems -> problem',
#  'procedures -> procedure',
#  'processes -> process',
#  'processors -> processor',
#  'produces -> produce',
#  'products -> product',
#  'profiles -> profile',
#  'programs -> program',
#  'progresses -> progress',
#  'projections -> projection',
#  'projects -> project',
#  'prompts -> prompt',
#  'prongs -> prong',
#  'propellers -> propeller',
#  'properties -> property',
#  'proportions -> proportion',
#  'proteins -> protein',
#  'protocols -> protocol',
#  'protrusions -> protrusion',
#  'protuberances -> protuberance',
#  'providers -> provider',
#  'provisions -> provision',
#  'pulleys -> pulley',
#  'pulls -> pull',
#  'pulses -> pulse',
#  'pumps -> pump',
#  'punches -> punch',
#  'purposes -> purpose',
#  'pushers -> pusher',
#  'pushes -> push',
#  'quadrants -> quadrant',
#  'qualities -> quality',
#  'quantities -> quantity',
#  'queries -> query',
#  'questions -> question',
#  'queues -> queue',
#  'races -> race',
#  'racks -> rack',
#  'radiators -> radiator',
#  'radios -> radio',
#  ...]

# %% [markdown]
# ### 5.4 Remove Stopwords
# Stopwords are those words that do not contribute to the lexical content.
# Removing the stopwords reduces both the number of tokens, and the vocabulary.

# %%
# Out:
# Number of tokens: 	160811
# Vocabulary: 		8427
# Lexical Diversity: 	0.0524031316266

# %% [markdown]
# ### 5.5 Remove Most frequent and Least Frequent Words
# Document frequency is used to identify the most and least frequently appearing words. The document frequency is the count of documents (abstracts) that the word appears in. In calculating the document frequency, the set of 'lemmatised' tokens excluding stopwords is used.

# %% [markdown]
# #### Identify most and least frequent words
#
# Tasks:
# - Identify the top 20 most important words based on document frequency (i.e. number of documents the word appears in).
# - Identify those words which appear in only one abstract
# - Remove the most frequent and least frequent words

# %% [markdown]
# #### Most frequent words
# The most frequent words are those that appear in more than 100 patents.
# These are subsequently removed from the token set.

# %%
# Out:
# 20 words identified appearing in more than 100 patents
# Frequent words: [u'includes', u'one', u'first', u'method', u'second', u'device', u'system', u'provided', u'ha', u'least', u'portion', u'plurality', u'surface', u'apparatus', u'including', u'may', u'end', u'control', u'connected', u'invention']

# %%
# Out:
# Number of tokens: 	139533
# Vocabulary: 		8407
# Lexical Diversity: 	0.0602509800549

# %% [markdown]
# #### Least frequent words

# %%
# Out:
# 3596 words identified appearing in only one abstract across all patents
# e.g. [u'secondly', u'repositioning', u'saturating', u'similarity', u'dissolution', u'degradable', u'desirable', u'desirably', u'tensile', u'oldest']

# %%
# Out:
# Number of tokens: 	133670
# Vocabulary: 		4811
# Lexical Diversity: 	0.0359916211566

# %% [markdown]
# ### 5.6 Identify bigrams
# A bigram is a continguous sequence of two words. The nltk collocations packages is used to identify bigrams contained within the set of abstracts.
#
# Bigrams require collocation and as such the lemmatised tokenised sentence, including stopwords (abstract_2) is used.
#
# To identify the 100 most meaningful bigrams, a filter is applied to remove bigrams that include stopwords or words contained within the most frequent word list.
#
# Additional 'ignore' words have also been filtered from the set of bigrams to exclude non-meaningful results. These additional ignored words are mainly either 'positional' descriptors (e.g. 'left', 'right', 'inner', 'outer'), or generalised terms (e.g. 'make', 'combining', 'configured', 'whether') that are considered to not contribute to the lexical content. The context of terms added to the ignore_other list was assessed using the nltk 'concordance' command.

# %%
# Out:
# Displaying 25 of 85 matches:
# ed characteristic value determining whether first measured characteristic value
# ed characteristic value determining whether second measured characteristic valu
# t temperature threshold determining whether temperature data exceeds second tem
# xceeds second temperature threshold whether pressure data exceeds pressure thre
# ke available information concerning whether electrical current flowing resistan
# utput first check signal indicating whether access request directed first segme
# tput second check signal indicating whether second executing unit active well c
#  part response method may determine whether dispense cash roll sheet type store
# detecting aftercooling time judging whether smaller predetermined cooling time
# cond temperature difference judging whether ratio second temperature difference
#  therein winning number determining whether offer prize based determined winnin
# referably form microphone detecting whether practicing swing timely premature l
#  suction port judgment device judge whether replacement gas liquid separating m
# g gas purge judging section judging whether purging operation purge section req
# herwise electronic device determine whether device enter mode effective control
# current judging module used judging whether value first voltage smaller default
# cy reference clock signal according whether lock completion signal enabled phas
# rticular time frame order determine whether initiate action system tracking loc
# arison result accordingly determine whether plurality source driver plurality g
# decision section make determination whether first item information permitted us
# stored plurality capacitor tracking whether current state data stored plurality
# cy column activation signal control whether activate global line connected pad
#  number equal greater one detecting whether monitoring bit error self refresh c
# usting self refresh cycle according whether monitoring bit error integrated cir
# en allocated queue token indicative whether predetermined amount data may deque

# %% [markdown]
# #### Tokenising abstracts with unigrams and bigrams
# To complete the text analysis, the original abstract text is re-tokenised to include the multi-word bigrams using the nltk MWETokenizer.  This replaces the collocated tokens in the abstract text, with the multiwords identified.
#
# Abstract_2 (the lemmatised form of the tokens) is used as the initial input.

# %%
# Out:
# Number of tokens: 	130762
# Vocabulary: 		4906
# Lexical Diversity: 	0.0375185451431

# %% [markdown]
# ### 5.7 Final Vocabulary
# The final vocabulary at the end of pre-processing is the set of tokens remaining. The vocab size generated in this manner should be the same as that generated by the CountVectorizer used to create the sparse count vectors below.

# %%
# Out:
# 4906

# %% [markdown]
# ## 6. Generate sparse count vectors
#
#   **CountVector:**  converts a collection of text documents to a matrix of token counts.
#
# Generate the count vector representation for each patent asbstract.
# Initialise the "CountVector" object: since we have pre-processed all the abstracts, the default value ('None') is used for the parameters, "tokenizer", "preprocessor" and "stop_words".

# %%
# Out:
# (2500, 4906)

# %% [markdown]
# ### 6.1 Vocabulary resulting from CountVectorizer
# The vocabulary resulting from the CountVectorizer is used to create a dictionary, and written to the file vocab.txt

# %% [markdown]
# ### 6.2 Create the spare vector count and write to file
# The spare vector count is produced by reducing the matrix produced by the CountVectorizer to those items of the vocabulary with a count greater than zero.

# %% [markdown]
# ### 6.3 Final Checks for Sparse Count Vector and  Pre-processing of text
# To complete the pre-processing, a check of the tokenisation, lemmatisation, removal of words, replacememt of bigrams, and the final creation of sparse count vectors can be checked by examining an individual patent as shown below.
#
# The sample patent below shows the following:
#   1.   orignal abstract text
#   2.   initial tokenisation, including stop words
#   3.   lemmatisation, e.g. surfaces -> surface
#   4.   stopwords removed, e.g. 'for', 'is', 'and'
#   5.   most and least frequent words removed, e.g. 'method', 'includes', 'first', 'second'.
#   6.   bigrams tokens, e.g. 'semiconducter_substrate'
#   7.   reduction to sparse vector
#   8.   check of cross-reference to vocabulary

# %%
## Checking pre-processing steps to completion for an individual patent
# Out:
# 1. Original <abstracts>:
# A method for manufacturing a photodiode array includes providing a semiconductor substrate having first and second main surfaces opposite to each other. The semiconductor substrate has a first layer of a first conductivity proximate the first main surface and a second layer of a second conductivity proximate the second main surface. A via is formed in the substrate which extends to a first depth position relative to the first main surface. The via has a first aspect ratio. Generally simultaneously with forming the via, an isolation trench is formed in the substrate spaced apart from the via which extends to a second depth position relative to the first main surface. The isolation trench has a second aspect ratio different from the first aspect ratio.
#
# 2. Tokenised <abstracts_1>:
# [u'method', u'for', u'manufacturing', u'photodiode', u'array', u'includes', u'providing', u'semiconductor', u'substrate', u'having', u'first', u'and', u'second', u'main', u'surfaces', u'opposite', u'each', u'other', u'the', u'semiconductor', u'substrate', u'has', u'first', u'layer', u'first', u'conductivity', u'proximate', u'the', u'first', u'main', u'surface', u'and', u'second', u'layer', u'second', u'conductivity', u'proximate', u'the', u'second', u'main', u'surface', u'via', u'formed', u'the', u'substrate', u'which', u'extends', u'first', u'depth', u'position', u'relative', u'the', u'first', u'main', u'surface', u'the', u'via', u'has', u'first', u'aspect', u'ratio', u'generally', u'simultaneously', u'with', u'forming', u'the', u'via', u'isolation', u'trench', u'formed', u'the', u'substrate', u'spaced', u'apart', u'from', u'the', u'via', u'which', u'extends', u'second', u'depth', u'position', u'relative', u'the', u'first', u'main', u'surface', u'the', u'isolation', u'trench', u'has', u'second', u'aspect', u'ratio', u'different', u'from', u'the', u'first', u'aspect', u'ratio']
#
# 3. After lemmatisation <abstracts_2>:
# [u'method', u'for', u'manufacturing', u'photodiode', u'array', u'includes', u'providing', u'semiconductor', u'substrate', u'having', u'first', u'and', u'second', u'main', u'surface', u'opposite', u'each', u'other', u'the', u'semiconductor', u'substrate', u'ha', u'first', u'layer', u'first', u'conductivity', u'proximate', u'the', u'first', u'main', u'surface', u'and', u'second', u'layer', u'second', u'conductivity', u'proximate', u'the', u'second', u'main', u'surface', u'via', u'formed', u'the', u'substrate', u'which', u'extends', u'first', u'depth', u'position', u'relative', u'the', u'first', u'main', u'surface', u'the', u'via', u'ha', u'first', u'aspect', u'ratio', u'generally', u'simultaneously', u'with', u'forming', u'the', u'via', u'isolation', u'trench', u'formed', u'the', u'substrate', u'spaced', u'apart', u'from', u'the', u'via', u'which', u'extends', u'second', u'depth', u'position', u'relative', u'the', u'first', u'main', u'surface', u'the', u'isolation', u'trench', u'ha', u'second', u'aspect', u'ratio', u'different', u'from', u'the', u'first', u'aspect', u'ratio']
#
# 4. Remove stopwords <abstracts_3>:
# [u'method', u'manufacturing', u'photodiode', u'array', u'includes', u'providing', u'semiconductor', u'substrate', u'first', u'second', u'main', u'surface', u'opposite', u'semiconductor', u'substrate', u'ha', u'first', u'layer', u'first', u'conductivity', u'proximate', u'first', u'main', u'surface', u'second', u'layer', u'second', u'conductivity', u'proximate', u'second', u'main', u'surface', u'via', u'formed', u'substrate', u'extends', u'first', u'depth', u'position', u'relative', u'first', u'main', u'surface', u'via', u'ha', u'first', u'aspect', u'ratio', u'generally', u'simultaneously', u'forming', u'via', u'isolation', u'trench', u'formed', u'substrate', u'spaced', u'apart', u'via', u'extends', u'second', u'depth', u'position', u'relative', u'first', u'main', u'surface', u'isolation', u'trench', u'ha', u'second', u'aspect', u'ratio', u'different', u'first', u'aspect', u'ratio']
#
# 5. Remove most and lest frequent <abstracts_5>:
# [u'manufacturing', u'photodiode', u'array', u'providing', u'semiconductor', u'substrate', u'main', u'opposite', u'semiconductor', u'substrate', u'layer', u'conductivity', u'proximate', u'main', u'layer', u'conductivity', u'proximate', u'main', u'via', u'formed', u'substrate', u'extends', u'depth', u'position', u'relative', u'main', u'via', u'aspect', u'ratio', u'generally', u'simultaneously', u'forming', u'via', u'isolation', u'trench', u'formed', u'substrate', u'spaced', u'apart', u'via', u'extends', u'depth', u'position', u'relative', u'main', u'isolation', u'trench', u'aspect', u'ratio', u'different', u'aspect', u'ratio']
#
# 6. Replace bigram <abstracts_mw>:
# [u'manufacturing', u'photodiode', u'array', u'providing', u'semiconductor_substrate', u'main', u'opposite', u'semiconductor_substrate', u'layer', u'conductivity', u'proximate', u'main', u'layer', u'conductivity', u'proximate', u'main', u'via', u'formed', u'substrate', u'extends', u'depth', u'position', u'relative', u'main', u'via', u'aspect', u'ratio', u'generally', u'simultaneously', u'forming', u'via', u'isolation', u'trench', u'formed', u'substrate', u'spaced', u'apart', u'via', u'extends', u'depth', u'position', u'relative', u'main', u'isolation', u'trench', u'aspect', u'ratio', u'different', u'aspect', u'ratio']
#
# 7. Sparse vector:
# 234:1,272:1,284:3,877:2,1192:2,1256:1,1708:2,1890:2,1891:1,1960:1,2414:2,2492:2,2631:5,2663:1,2963:1,3161:1,3261:2,3425:1,3429:2,3513:3,3635:2,3939:2,4056:1,4131:1,4311:2,4607:2,4757:4
#
# 8. Vocab checks:
# ('word:', [(234, u'apart'), (272, u'array'), (284, u'aspect'), (877, u'conductivity'), (1192, u'depth'), (1256, u'different'), (1708, u'extends'), (1890, u'formed'), (1891, u'forming'), (1960, u'generally'), (2414, u'isolation'), (2492, u'layer'), (2631, u'main'), (2663, u'manufacturing'), (2963, u'opposite'), (3161, u'photodiode'), (3261, u'position'), (3425, u'providing'), (3429, u'proximate'), (3513, u'ratio'), (3635, u'relative'), (3939, u'semiconductor_substrate'), (4056, u'simultaneously'), (4131, u'spaced'), (4311, u'substrate'), (4607, u'trench'), (4757, u'via')])

# %% [markdown]
# ### 7.Summary:
# ##### 1. Section 3, showed how to split  an aggregated XML file into seprate standalone files.
# ##### 2. Section 4.1,  showed how to get the patents classification from a highly nested XML files into structurally flat text file, using xml parsing.
# ##### 3. Section  4.2, deomnstrated how to get the citation list per patent from it's xml attribute.
# ##### 4. Section 4.3, illustrates the code to get the referencing count per patent
# ##### 5. Section 5 & 6, Showed the process of wrangling the abstract text to get into more useful numerical formate for further data analyis.
#
# The wrangling cycle illustrated here, shows how a text starting with bellow statistics, ended up reduced to more sparse text while conserving the main text feature. The end output of this text, should serve a good basline line for further topic modelling, feature analysis as well as a basis for an efficient retrival system .
#
#
# ######################### Text Statistics Before Wrangling ##################################
#
# Total number of words: 277617<br>
# Total number of vocabs: 9855<br>
# Lexical diversity is : 3.549855 %<br>
#
# ######################### Final Text Statistics After Wranling ##################################
#
# Total number of words: 131714<br>
# Total number of vocabs: 5572<br>
# Lexical diversity is : 4.230378 %<br>
